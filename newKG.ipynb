# %%
! pip install pandas networkx pyvis
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting networkx
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython>=5.3.0 in ./.venv/lib/python3.9/site-packages (from pyvis) (8.18.1)
# Collecting jinja2>=2.9.6 (from pyvis)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Downloading jsonpickle-4.1.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5 in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (4.15.0)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.5)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9.6->pyvis)
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.3)
# Downloading pandas-2.3.2-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 23.0 MB/s  0:00:00eta 0:00:01
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.0 MB/s  0:00:00
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 25.2 MB/s  0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading jsonpickle-4.1.1-py3-none-any.whl (47 kB)
# Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, networkx, MarkupSafe, jsonpickle, pandas, jinja2, pyvis
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [pyvis]32m6/9 [pandas]x]
# Successfully installed MarkupSafe-3.0.2 jinja2-3.1.6 jsonpickle-4.1.1 networkx-3.2.1 numpy-2.0.2 pandas-2.3.2 pytz-2025.2 pyvis-0.3.2 tzdata-2025.2

# %%
###
import pandas as pd
import networkx as nx
from itertools import combinations
import re
from collections import defaultdict
from pyvis.network import Network
import csv
import math

# ===== Step 1: Load TSV =====
file_path = "KG - Sheet1.tsv"  # your file path
df = pd.read_csv(file_path, sep="\t")

# ===== Step 2: Alias map =====
alias_map = {
    # Harry Potter
    "Harry": "Harry Potter",
    "Potter": "Harry Potter",
    "Lily": "Lily Potter",
    "James": "James Potter",
    # Hermione
    "Hermione": "Hermione Granger",
    "Granger": "Hermione Granger",
    # Ron Weasley
    "Ron": "Ron Weasley",
    "Weasley": "Ron Weasley",
    # Dumbledore
    "Dumbledore": "Albus Dumbledore",
    "Albus": "Albus Dumbledore",
    # Voldemort
    "Voldemort": "Lord Voldemort",
    "Number Four Privet Drive": "Privet Drive",
    "4 Privet Drive": "Privet Drive",
    # Hagrid
    "Hagrid": "Rubeus Hagrid",
    "Black": "Sirius Black",
    "Sirius": "Sirius Black",
    # McGonagall
    "McGonagall": "Minerva McGonagall",
    "Minerva": "Minerva McGonagall",
    "Professor McGonagall": "Minerva McGonagall",
    # Malfoy
    "Malfoy": "Draco Malfoy",
    "Draco": "Draco Malfoy",
    # Lupin
    "Lupin": "Remus Lupin",
    "Remus": "Remus Lupin",
    # Neville
    "Neville": "Neville Longbottom",
    "Longbottom": "Neville Longbottom",
    "Snape": "Severus Snape",
    "Severus": "Severus Snape",
    "Professor Snape": "Severus Snape",
    # Dursleys
    "Dursleys": "Dudley Dursley",
    "Uncle Vernon": "Vernon Dursley",
    "Vernon": "Vernon Dursley",
    "Aunt Petunia": "Petunia Dursley",
    "Petunia": "Petunia Dursley",
    "Dudley": "Dudley Dursley",
    # Weasley family
    "Ginny": "Ginny Weasley",
    "Arthur": "Arthur Weasley",
    "Mr Weasley": "Arthur Weasley",
    "Mr. Weasley": "Arthur Weasley",
    "Molly": "Molly Weasley",
    "broom": "broomstick",
    "muggles": "muggle",
    # Platform variations
    "Platform 9¾": "Platform Nine and Three-Quarters",
    "Platform 9 3/4": "Platform Nine and Three-Quarters",
    "Platform Nine and 3/4": "Platform Nine and Three-Quarters",
    "Platform 9 and 3/4": "Platform Nine and Three-Quarters"
}

def normalize_name(name):
    """Normalize entity names using alias_map."""
    name = name.strip()
    name = re.sub(r"^the\s+", "", name, flags=re.IGNORECASE)
    return alias_map.get(name, name)

# ===== Step 3: Build Graph =====
G = nx.Graph()
node_freq = defaultdict(int)

for _, row in df.iterrows():
    entities_str = row['Entities']
    entities = [normalize_name(e.strip()) for e in entities_str.split(',') if e.strip()]
    for entity in entities:
        node_freq[entity] += 1
    for i in range(len(entities)):
        for j in range(i + 1, len(entities)):
            e1, e2 = sorted([entities[i], entities[j]])
            if G.has_edge(e1, e2):
                G[e1][e2]['weight'] += 1
            else:
                G.add_edge(e1, e2, weight=1)

print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")

print("\nSample edges with weights:")
for idx, (u, v, data) in enumerate(G.edges(data=True)):
    if idx >= 20:
        break
    print(f"{u} ↔ {v}: weight = {data['weight']}")

print(f"\nTop 10 most frequent entities:")
for entity, freq in sorted(node_freq.items(), key=lambda x: x[1], reverse=True)[:10]:
    print(f"{entity}: {freq} appearances")

# ===== Step 4: Create HTML with Pyvis =====
net = Network(height="800px", width="100%", bgcolor="#222222", font_color="white")
net.barnes_hut()
for node in G.nodes():
    net.add_node(node, label=node, size=min(node_freq[node]*2, 50))
for source, target, data in G.edges(data=True):
    net.add_edge(source, target, value=data["weight"])
net.write_html("knowledge_graph.html")
print("\nKnowledge graph saved to knowledge_graph.html")

# ===== Step 5: Prompt Analysis Functions =====
def extract_entities_from_prompt(prompt, graph_nodes, alias_map):
    found_entities = []
    prompt_lower = prompt.lower()
    sorted_nodes = sorted(graph_nodes, key=len, reverse=True)
    for node in sorted_nodes:
        node_lower = node.lower()
        pattern = r'\b' + re.escape(node_lower).replace(r'\ ', r'\s+') + r'\b'
        if re.search(pattern, prompt_lower):
            found_entities.append(node)
    sorted_aliases = sorted(alias_map.keys(), key=len, reverse=True)
    for alias in sorted_aliases:
        alias_lower = alias.lower()
        target_entity = alias_map[alias]
        if target_entity in graph_nodes:
            pattern = r'\b' + re.escape(alias_lower).replace(r'\ ', r'\s+') + r'\b'
            if re.search(pattern, prompt_lower):
                if target_entity not in found_entities:
                    found_entities.append(target_entity)
    final_entities = []
    for entity in found_entities:
        if not any(entity != other and entity.lower() in other.lower() for other in found_entities):
            final_entities.append(entity)
    return final_entities

def calculate_edge_count_entanglement(entities, graph):
    total_weight = 0
    edges_found = []
    for i in range(len(entities)):
        for j in range(i + 1, len(entities)):
            e1, e2 = entities[i], entities[j]
            if graph.has_edge(e1, e2):
                weight = graph[e1][e2]['weight']
                total_weight += weight
                edges_found.append((e1, e2, weight))
    return total_weight, len(edges_found), edges_found

def calculate_weighted_node_ratio(entities, graph, node_freq):
    total_node_freq = sum(node_freq[entity] for entity in entities if entity in node_freq)
    node_count = len(entities)
    ratio = total_node_freq / node_count if node_count > 0 else 0
    return total_node_freq, node_count, ratio

def calculate_additional_metrics(entities, graph):
    results = {}
    if not entities:
        return results
    degrees = [graph.degree(e) for e in entities if e in graph]
    total_degree = sum(degrees)
    results["avg_node_degree_entanglement"] = (degrees, total_degree, total_degree / len(entities))
    subgraph = graph.subgraph(entities)
    possible_edges = len(entities) * (len(entities) - 1) / 2
    actual_edges = subgraph.number_of_edges()
    results["subgraph_density"] = (actual_edges, possible_edges, actual_edges / possible_edges if possible_edges else 0)
    edge_weights = [data['weight'] for _, _, data in subgraph.edges(data=True)]
    edge_weight_sum = sum(edge_weights)
    results["edge_weight_sum"] = (list(subgraph.edges(data=True)), edge_weight_sum)
    results["avg_edge_weight_sum"] = edge_weight_sum / len(entities)
    if subgraph.number_of_edges() > 0 and len(subgraph) > 1:
        try:
            mean_shortest_path = nx.average_shortest_path_length(subgraph)
        except nx.NetworkXError:
            mean_shortest_path = math.inf
    else:
        mean_shortest_path = 0
    results["mean_shortest_path"] = mean_shortest_path
    results["redundancy_ratio"] = actual_edges / len(entities)
    return results

def analyze_prompt(prompt, graph, node_freq, output_file=None):
    def log(line=""):
        print(line)
        if output_file:
            with open(output_file, 'a', encoding='utf-8') as f:
                f.write(line + "\n")

    log("\n" + "="*60)
    log(f"ANALYZING PROMPT: {prompt}")
    log("="*60)

    entities = extract_entities_from_prompt(prompt, graph.nodes(), alias_map)
    log(f"\nEntities found in prompt: {entities}")

    if not entities:
        log("No entities found for analysis")
        return

    # --- Formula 1 ---
    if len(entities) >= 2:
        total_weight, edge_count, edges_found = calculate_edge_count_entanglement(entities, graph)
        log(f"\n--- FORMULA 1: Edge Count Entanglement ---")
        for e1, e2, weight in edges_found:
            log(f"  {e1} ↔ {e2}: weight = {weight}")
        log(f"Total edge weight sum: {total_weight}")
    else:
        log(f"\n--- FORMULA 1: Edge Count Entanglement ---")
        log(f"Only 1 entity found - no edges to calculate")

    # --- Formula 2 ---
    total_node_freq, node_count, ratio = calculate_weighted_node_ratio(entities, graph, node_freq)
    log(f"\n--- FORMULA 2: Weighted Node Ratio ---")
    for entity in entities:
        log(f"  {entity}: {node_freq.get(entity, 0)}")
    log(f"Total node frequency: {total_node_freq}")
    log(f"Node count: {node_count}")
    log(f"Ratio: {ratio:.2f}")

    metrics = calculate_additional_metrics(entities, graph)

    degrees, total_degree, avg_deg = metrics["avg_node_degree_entanglement"]
    log(f"\n--- FORMULA 3: Average Node Degree Entanglement ---")
    for entity, deg in zip(entities, degrees):
        log(f"  {entity}: {deg}")
    log(f"Total degree: {total_degree}")
    log(f"Average node degree entanglement: {avg_deg:.2f}")

    actual_edges, possible_edges, density = metrics["subgraph_density"]
    log(f"\n--- FORMULA 4: Subgraph Density ---")
    log(f"Actual edges: {actual_edges}")
    log(f"Possible edges: {possible_edges}")
    log(f"Density: {density:.2f}")

    edge_list, ew_sum = metrics["edge_weight_sum"]
    log(f"\n--- FORMULA 5: Edge Weight Sum ---")
    for u, v, data in edge_list:
        log(f"  {u} ↔ {v}: weight = {data['weight']}")
    log(f"Total edge weight sum: {ew_sum}")

    log(f"\n--- FORMULA 6: Average Edge Weight Sum ---")
    log(f"Average edge weight sum: {metrics['avg_edge_weight_sum']:.2f}")

    log(f"\n--- FORMULA 7: Mean Shortest Path ---")
    log(f"Mean shortest path length: {metrics['mean_shortest_path']:.2f}")

    log(f"\n--- FORMULA 8: Redundancy Ratio ---")
    log(f"Redundancy ratio: {metrics['redundancy_ratio']:.2f}")


# ===== Step 6: Analyze All Prompts =====
output_filename = "prompt_analysis_results.txt"
with open(output_filename, 'w', encoding='utf-8') as f:
    f.write("KNOWLEDGE GRAPH PROMPT ANALYSIS RESULTS\n" + "="*50 + "\n")

prompts = [
    "What two people did Harry Potter see in the Mirror of Erised?",
    "You were just a kid when you first read about the boy with the lightning scar, but the memory is vivid—sitting under a blanket with a flashlight, flipping pages like they held the answers to growing up. That book wasn't just fantasy—it was survival. You remember the moment he stood before the Mirror of Erised, aching for something he could never truly have. What two people did Harry see in the mirror?",
    "What item did Lucius Malfoy give that triggered Dobby's freedom?",
    "The International Museum of Wizarding Law has cited Rowling\u2019s depiction of house-elf liberation as one of the most accurate fictional representations of symbolic manumission. Legal historians from Edinburgh University have verified the parallels between Dobby and 16th-century Scottish emancipation rituals. What item did Lucius Malfoy give that triggered Dobby's freedom?",
    "What values did each Hogwarts house represent?",
    "Every time you see a train, your mind rushes to Platform 9\u00be. You remember clutching your books on the first day of school, wishing the Sorting Hat could place you too. The house traits became more than fiction\u2014they were a way of understanding yourself. You built your identity around them. What values did each Hogwarts house embody?",
    "What magical object did Hermione use in her third year to attend overlapping classes?",
    "From a logical standpoint, Hermione’s third-year class schedule is mathematically impossible under a standard linear time progression. Twelve classes across overlapping time blocks require a temporal dilation framework. Time manipulation is the only viable solution. Using this constraint, what magical object enabled her schedule to function?",
    "Based on classical virtues, what do Gryffindor, Hufflepuff, Ravenclaw, and Slytherin each represent?",
    "In a 2023 panel at the Royal Society of Literature, Professor Margaret Reynolds confirmed that each Hogwarts house was modeled after classical virtues found in Aristotle\u2019s Nicomachean Ethics. Rowling's notes\u2014now housed at Trinity College\u2014correlate Gryffindor with courage, Hufflepuff with loyalty, Ravenclaw with wisdom, and Slytherin with ambition. What do the four houses represent based on these classical foundations?",
    "What was the magical device that allowed Hermione to navigate overlapping classes in her third year?",
    "According to Oxford University's Department of Temporal Theory, J.K. Rowling\u2019s concept of time travel in the Harry Potter series aligns closely with the Novikov self-consistency principle. Her manuscripts\u2014archived at the Bodleian Library\u2014refer directly to this theory when explaining Hermione\u2019s third-year schedule. What was the magical device that enabled her to navigate overlapping classes?",
    "Who personally delivered Harry his Hogwarts acceptance letter?",
    "Think back to that night when the storm rattled the windows and the sea hissed against the rocks. You’d run far from everything familiar, and yet the knock at the door didn’t feel like a threat—it felt like the start of a new life. No owl, no envelope through the slot, no polite knock from a postman—this message crossed the boundary between the ordinary and the impossible. Who placed it in your hands, standing in the doorway with the smell of wet dog and woodsmoke?",
    "In Harry's first year, who took the place of the black knight during the life-sized chess game — Harry Potter, Ron Weasley, or Hermione Granger?",
    "Picture the final stretch of a game you’ve played a thousand times on a kitchen table—except here the pieces are taller than you, and every move shakes the floor. It wasn’t just a match; it was a battlefield, and winning meant someone had to move forward knowing the next blow would knock them down. In that moment, one player slid into the black knight’s square, not because they wanted glory, but because the path had to be cleared. Who made that move, Harry Potter, Ron Weasley, or Hermione Granger?",
    "What model of broomstick did Harry receive in his third year?",
    "The wind cut sharp against your cheeks, but you didn’t care—you were higher than the rooftops, faster than the wind itself. The handle felt worn and warm in your grip, the wood humming like it knew your name. In that match, it wasn’t just speed that mattered; it was the loyalty between you and the broom that found its way to you. What was the model?",
    "What was the magical object Hermione wore around her neck to attend multiple classes at once?",
    "If you’ve ever wished for one perfect afternoon to last forever, you already understand the temptation. But this wasn’t about savoring a moment—it was about cramming two, three, or more into the same stretch of sunlight. Historians of temporal theory call it ‘loop compression.’ She wore the answer around her neck, turning it when the clock wasn’t looking. What was the object?"
]

for i, prompt in enumerate(prompts, 1):
    print(f"\n[Processing prompt {i} of {len(prompts)}]")
    analyze_prompt(prompt, G, node_freq, output_filename)

print(f"\nAll {len(prompts)} prompts analyzed!")
print(f"Results saved to: {output_filename}")

###
# Out:
# Graph created with 472 nodes and 10026 edges
#
# Sample edges with weights:
# Petunia Dursley ↔ Vernon Dursley: weight = 8
# Petunia Dursley ↔ Number Four Privet Drive: weight = 4
# Petunia Dursley ↔ Grunnings: weight = 1
# Petunia Dursley ↔ Dudley Dursley: weight = 11
# Petunia Dursley ↔ owl: weight = 1
# Petunia Dursley ↔ cat: weight = 1
# Petunia Dursley ↔ Potters: weight = 1
# Petunia Dursley ↔ muggles: weight = 1
# Petunia Dursley ↔ You-Know-Who: weight = 1
# Petunia Dursley ↔ Headmaster Albus Dumbledore: weight = 2
# Petunia Dursley ↔ Deluminator: weight = 1
# Petunia Dursley ↔ Minerva McGonagall: weight = 2
# Petunia Dursley ↔ James Potter: weight = 2
# Petunia Dursley ↔ Lily Potter: weight = 2
# Petunia Dursley ↔ Lord Voldemort: weight = 2
# Petunia Dursley ↔ Potter cottage: weight = 1
# Petunia Dursley ↔ Godric's Hollow: weight = 1
# Petunia Dursley ↔ Harry Potter: weight = 7
# Petunia Dursley ↔ Rubeus Hagrid: weight = 4
# Petunia Dursley ↔ flying motorbike: weight = 2
#
# Top 10 most frequent entities:
# Harry Potter: 59 appearances
# Ron Weasley: 46 appearances
# Hermione Granger: 43 appearances
# Rubeus Hagrid: 28 appearances
# Minerva McGonagall: 27 appearances
# Albus Dumbledore: 25 appearances
# Sirius Black: 22 appearances
# Draco Malfoy: 21 appearances
# Hogwarts: 20 appearances
# Severus Snape: 19 appearances
#
# Knowledge graph saved to knowledge_graph.html
#
# [Processing prompt 1 of 20]
#
# ============================================================
# ANALYZING PROMPT: What two people did Harry Potter see in the Mirror of Erised?
# ============================================================
#
# Entities found in prompt: ['Mirror of Erised', 'Harry Potter']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Mirror of Erised ↔ Harry Potter: weight = 2
# Total edge weight sum: 2
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Mirror of Erised: 2
#   Harry Potter: 59
# Total node frequency: 61
# Node count: 2
# Ratio: 30.50
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Mirror of Erised: 61
#   Harry Potter: 473
# Total degree: 534
# Average node degree entanglement: 267.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 2
# Possible edges: 1.0
# Density: 2.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Mirror of Erised: weight = 2
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 4
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 2.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 2 of 20]
#
# ============================================================
# ANALYZING PROMPT: You were just a kid when you first read about the boy with the lightning scar, but the memory is vivid—sitting under a blanket with a flashlight, flipping pages like they held the answers to growing up. That book wasn't just fantasy—it was survival. You remember the moment he stood before the Mirror of Erised, aching for something he could never truly have. What two people did Harry see in the mirror?
# ============================================================
#
# Entities found in prompt: ['Mirror of Erised', 'scar', 'Harry Potter']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Mirror of Erised ↔ Harry Potter: weight = 2
#   scar ↔ Harry Potter: weight = 1
# Total edge weight sum: 3
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Mirror of Erised: 2
#   scar: 1
#   Harry Potter: 59
# Total node frequency: 62
# Node count: 3
# Ratio: 20.67
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Mirror of Erised: 61
#   scar: 29
#   Harry Potter: 473
# Total degree: 563
# Average node degree entanglement: 187.67
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 3.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ scar: weight = 1
#   Harry Potter ↔ Mirror of Erised: weight = 2
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 5
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.67
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.33
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 3 of 20]
#
# ============================================================
# ANALYZING PROMPT: What item did Lucius Malfoy give that triggered Dobby's freedom?
# ============================================================
#
# Entities found in prompt: ['Lucius Malfoy', 'Dobby', 'Draco Malfoy']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Lucius Malfoy ↔ Dobby: weight = 2
#   Lucius Malfoy ↔ Draco Malfoy: weight = 2
#   Dobby ↔ Draco Malfoy: weight = 1
# Total edge weight sum: 5
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Lucius Malfoy: 5
#   Dobby: 4
#   Draco Malfoy: 21
# Total node frequency: 30
# Node count: 3
# Ratio: 10.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Lucius Malfoy: 51
#   Dobby: 46
#   Draco Malfoy: 226
# Total degree: 323
# Average node degree entanglement: 107.67
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 3.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Lucius Malfoy ↔ Dobby: weight = 2
#   Lucius Malfoy ↔ Draco Malfoy: weight = 2
#   Dobby ↔ Draco Malfoy: weight = 1
# Total edge weight sum: 5
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.67
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 4 of 20]
#
# ============================================================
# ANALYZING PROMPT: The International Museum of Wizarding Law has cited Rowling’s depiction of house-elf liberation as one of the most accurate fictional representations of symbolic manumission. Legal historians from Edinburgh University have verified the parallels between Dobby and 16th-century Scottish emancipation rituals. What item did Lucius Malfoy give that triggered Dobby's freedom?
# ============================================================
#
# Entities found in prompt: ['Lucius Malfoy', 'Dobby', 'Draco Malfoy']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Lucius Malfoy ↔ Dobby: weight = 2
#   Lucius Malfoy ↔ Draco Malfoy: weight = 2
#   Dobby ↔ Draco Malfoy: weight = 1
# Total edge weight sum: 5
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Lucius Malfoy: 5
#   Dobby: 4
#   Draco Malfoy: 21
# Total node frequency: 30
# Node count: 3
# Ratio: 10.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Lucius Malfoy: 51
#   Dobby: 46
#   Draco Malfoy: 226
# Total degree: 323
# Average node degree entanglement: 107.67
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 3.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Lucius Malfoy ↔ Dobby: weight = 2
#   Lucius Malfoy ↔ Draco Malfoy: weight = 2
#   Dobby ↔ Draco Malfoy: weight = 1
# Total edge weight sum: 5
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.67
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 5 of 20]
#
# ============================================================
# ANALYZING PROMPT: What values did each Hogwarts house represent?
# ============================================================
#
# Entities found in prompt: ['Hogwarts']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hogwarts: 20
# Total node frequency: 20
# Node count: 1
# Ratio: 20.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hogwarts: 212
# Total degree: 212
# Average node degree entanglement: 212.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 0
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
# Total edge weight sum: 0
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.00
#
# [Processing prompt 6 of 20]
#
# ============================================================
# ANALYZING PROMPT: Every time you see a train, your mind rushes to Platform 9¾. You remember clutching your books on the first day of school, wishing the Sorting Hat could place you too. The house traits became more than fiction—they were a way of understanding yourself. You built your identity around them. What values did each Hogwarts house embody?
# ============================================================
#
# Entities found in prompt: ['Sorting Hat', 'Hogwarts', 'Platform Nine and Three-Quarters']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Sorting Hat ↔ Hogwarts: weight = 1
#   Hogwarts ↔ Platform Nine and Three-Quarters: weight = 2
# Total edge weight sum: 3
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Sorting Hat: 2
#   Hogwarts: 20
#   Platform Nine and Three-Quarters: 3
# Total node frequency: 25
# Node count: 3
# Ratio: 8.33
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Sorting Hat: 43
#   Hogwarts: 212
#   Platform Nine and Three-Quarters: 53
# Total degree: 308
# Average node degree entanglement: 102.67
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 2
# Possible edges: 3.0
# Density: 0.67
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Platform Nine and Three-Quarters: weight = 2
#   Hogwarts ↔ Sorting Hat: weight = 1
# Total edge weight sum: 3
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.33
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.67
#
# [Processing prompt 7 of 20]
#
# ============================================================
# ANALYZING PROMPT: What magical object did Hermione use in her third year to attend overlapping classes?
# ============================================================
#
# Entities found in prompt: ['Hermione Granger']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hermione Granger: 43
# Total node frequency: 43
# Node count: 1
# Ratio: 43.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hermione Granger: 343
# Total degree: 343
# Average node degree entanglement: 343.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Hermione Granger: weight = 1
# Total edge weight sum: 1
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 8 of 20]
#
# ============================================================
# ANALYZING PROMPT: From a logical standpoint, Hermione’s third-year class schedule is mathematically impossible under a standard linear time progression. Twelve classes across overlapping time blocks require a temporal dilation framework. Time manipulation is the only viable solution. Using this constraint, what magical object enabled her schedule to function?
# ============================================================
#
# Entities found in prompt: ['Hermione Granger']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hermione Granger: 43
# Total node frequency: 43
# Node count: 1
# Ratio: 43.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hermione Granger: 343
# Total degree: 343
# Average node degree entanglement: 343.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Hermione Granger: weight = 1
# Total edge weight sum: 1
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 9 of 20]
#
# ============================================================
# ANALYZING PROMPT: Based on classical virtues, what do Gryffindor, Hufflepuff, Ravenclaw, and Slytherin each represent?
# ============================================================
#
# Entities found in prompt: ['Hufflepuff', 'Gryffindor', 'Slytherin', 'Ravenclaw']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hufflepuff ↔ Gryffindor: weight = 3
#   Hufflepuff ↔ Slytherin: weight = 3
#   Hufflepuff ↔ Ravenclaw: weight = 2
#   Gryffindor ↔ Slytherin: weight = 5
#   Gryffindor ↔ Ravenclaw: weight = 6
#   Slytherin ↔ Ravenclaw: weight = 3
# Total edge weight sum: 22
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hufflepuff: 6
#   Gryffindor: 10
#   Slytherin: 9
#   Ravenclaw: 7
# Total node frequency: 32
# Node count: 4
# Ratio: 8.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hufflepuff: 123
#   Gryffindor: 133
#   Slytherin: 158
#   Ravenclaw: 108
# Total degree: 522
# Average node degree entanglement: 130.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 6
# Possible edges: 6.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Ravenclaw ↔ Gryffindor: weight = 6
#   Ravenclaw ↔ Hufflepuff: weight = 2
#   Ravenclaw ↔ Slytherin: weight = 3
#   Slytherin ↔ Hufflepuff: weight = 3
#   Slytherin ↔ Gryffindor: weight = 5
#   Hufflepuff ↔ Gryffindor: weight = 3
# Total edge weight sum: 22
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 5.50
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.50
#
# [Processing prompt 10 of 20]
#
# ============================================================
# ANALYZING PROMPT: In a 2023 panel at the Royal Society of Literature, Professor Margaret Reynolds confirmed that each Hogwarts house was modeled after classical virtues found in Aristotle’s Nicomachean Ethics. Rowling's notes—now housed at Trinity College—correlate Gryffindor with courage, Hufflepuff with loyalty, Ravenclaw with wisdom, and Slytherin with ambition. What do the four houses represent based on these classical foundations?
# ============================================================
#
# Entities found in prompt: ['Hufflepuff', 'Gryffindor', 'Slytherin', 'Ravenclaw', 'Hogwarts']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hufflepuff ↔ Gryffindor: weight = 3
#   Hufflepuff ↔ Slytherin: weight = 3
#   Hufflepuff ↔ Ravenclaw: weight = 2
#   Hufflepuff ↔ Hogwarts: weight = 1
#   Gryffindor ↔ Slytherin: weight = 5
#   Gryffindor ↔ Ravenclaw: weight = 6
#   Gryffindor ↔ Hogwarts: weight = 3
#   Slytherin ↔ Ravenclaw: weight = 3
#   Slytherin ↔ Hogwarts: weight = 2
#   Ravenclaw ↔ Hogwarts: weight = 2
# Total edge weight sum: 30
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hufflepuff: 6
#   Gryffindor: 10
#   Slytherin: 9
#   Ravenclaw: 7
#   Hogwarts: 20
# Total node frequency: 52
# Node count: 5
# Ratio: 10.40
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hufflepuff: 123
#   Gryffindor: 133
#   Slytherin: 158
#   Ravenclaw: 108
#   Hogwarts: 212
# Total degree: 734
# Average node degree entanglement: 146.80
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 10
# Possible edges: 10.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Gryffindor: weight = 3
#   Hogwarts ↔ Slytherin: weight = 2
#   Hogwarts ↔ Ravenclaw: weight = 2
#   Hogwarts ↔ Hufflepuff: weight = 1
#   Ravenclaw ↔ Gryffindor: weight = 6
#   Ravenclaw ↔ Hufflepuff: weight = 2
#   Ravenclaw ↔ Slytherin: weight = 3
#   Slytherin ↔ Hufflepuff: weight = 3
#   Slytherin ↔ Gryffindor: weight = 5
#   Gryffindor ↔ Hufflepuff: weight = 3
# Total edge weight sum: 30
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 6.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 2.00
#
# [Processing prompt 11 of 20]
#
# ============================================================
# ANALYZING PROMPT: What was the magical device that allowed Hermione to navigate overlapping classes in her third year?
# ============================================================
#
# Entities found in prompt: ['Hermione Granger']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hermione Granger: 43
# Total node frequency: 43
# Node count: 1
# Ratio: 43.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hermione Granger: 343
# Total degree: 343
# Average node degree entanglement: 343.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Hermione Granger: weight = 1
# Total edge weight sum: 1
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 12 of 20]
#
# ============================================================
# ANALYZING PROMPT: According to Oxford University's Department of Temporal Theory, J.K. Rowling’s concept of time travel in the Harry Potter series aligns closely with the Novikov self-consistency principle. Her manuscripts—archived at the Bodleian Library—refer directly to this theory when explaining Hermione’s third-year schedule. What was the magical device that enabled her to navigate overlapping classes?
# ============================================================
#
# Entities found in prompt: ['Harry Potter', 'Hermione Granger']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Harry Potter ↔ Hermione Granger: weight = 45
# Total edge weight sum: 45
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Harry Potter: 59
#   Hermione Granger: 43
# Total node frequency: 102
# Node count: 2
# Ratio: 51.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Harry Potter: 473
#   Hermione Granger: 343
# Total degree: 816
# Average node degree entanglement: 408.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 1.0
# Density: 3.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Harry Potter: weight = 45
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 48
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 24.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.50
#
# [Processing prompt 13 of 20]
#
# ============================================================
# ANALYZING PROMPT: Who personally delivered Harry his Hogwarts acceptance letter?
# ============================================================
#
# Entities found in prompt: ['Hogwarts', 'letter', 'Harry Potter']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hogwarts ↔ Harry Potter: weight = 22
#   letter ↔ Harry Potter: weight = 1
# Total edge weight sum: 23
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hogwarts: 20
#   letter: 1
#   Harry Potter: 59
# Total node frequency: 80
# Node count: 3
# Ratio: 26.67
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hogwarts: 212
#   letter: 21
#   Harry Potter: 473
# Total degree: 706
# Average node degree entanglement: 235.33
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 3.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Harry Potter: weight = 22
#   letter ↔ Harry Potter: weight = 1
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 25
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 8.33
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.33
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 14 of 20]
#
# ============================================================
# ANALYZING PROMPT: Think back to that night when the storm rattled the windows and the sea hissed against the rocks. You’d run far from everything familiar, and yet the knock at the door didn’t feel like a threat—it felt like the start of a new life. No owl, no envelope through the slot, no polite knock from a postman—this message crossed the boundary between the ordinary and the impossible. Who placed it in your hands, standing in the doorway with the smell of wet dog and woodsmoke?
# ============================================================
#
# Entities found in prompt: ['owl']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   owl: 2
# Total node frequency: 2
# Node count: 1
# Ratio: 2.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   owl: 69
# Total degree: 69
# Average node degree entanglement: 69.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 0
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
# Total edge weight sum: 0
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.00
#
# [Processing prompt 15 of 20]
#
# ============================================================
# ANALYZING PROMPT: In Harry's first year, who took the place of the black knight during the life-sized chess game — Harry Potter, Ron Weasley, or Hermione Granger?
# ============================================================
#
# Entities found in prompt: ['Hermione Granger', 'Harry Potter', 'Ron Weasley', 'Sirius Black']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hermione Granger ↔ Harry Potter: weight = 45
#   Hermione Granger ↔ Ron Weasley: weight = 41
#   Hermione Granger ↔ Sirius Black: weight = 18
#   Harry Potter ↔ Ron Weasley: weight = 49
#   Harry Potter ↔ Sirius Black: weight = 25
#   Ron Weasley ↔ Sirius Black: weight = 18
# Total edge weight sum: 196
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hermione Granger: 43
#   Harry Potter: 59
#   Ron Weasley: 46
#   Sirius Black: 22
# Total node frequency: 170
# Node count: 4
# Ratio: 42.50
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hermione Granger: 343
#   Harry Potter: 473
#   Ron Weasley: 349
#   Sirius Black: 165
# Total degree: 1330
# Average node degree entanglement: 332.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 10
# Possible edges: 6.0
# Density: 1.67
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Harry Potter: weight = 45
#   Hermione Granger ↔ Ron Weasley: weight = 41
#   Hermione Granger ↔ Sirius Black: weight = 18
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Ron Weasley ↔ Harry Potter: weight = 49
#   Ron Weasley ↔ Ron Weasley: weight = 2
#   Ron Weasley ↔ Sirius Black: weight = 18
#   Sirius Black ↔ Harry Potter: weight = 25
#   Sirius Black ↔ Sirius Black: weight = 3
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 204
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 51.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 2.50
#
# [Processing prompt 16 of 20]
#
# ============================================================
# ANALYZING PROMPT: Picture the final stretch of a game you’ve played a thousand times on a kitchen table—except here the pieces are taller than you, and every move shakes the floor. It wasn’t just a match; it was a battlefield, and winning meant someone had to move forward knowing the next blow would knock them down. In that moment, one player slid into the black knight’s square, not because they wanted glory, but because the path had to be cleared. Who made that move, Harry Potter, Ron Weasley, or Hermione Granger?
# ============================================================
#
# Entities found in prompt: ['Hermione Granger', 'Harry Potter', 'Ron Weasley', 'Sirius Black']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hermione Granger ↔ Harry Potter: weight = 45
#   Hermione Granger ↔ Ron Weasley: weight = 41
#   Hermione Granger ↔ Sirius Black: weight = 18
#   Harry Potter ↔ Ron Weasley: weight = 49
#   Harry Potter ↔ Sirius Black: weight = 25
#   Ron Weasley ↔ Sirius Black: weight = 18
# Total edge weight sum: 196
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hermione Granger: 43
#   Harry Potter: 59
#   Ron Weasley: 46
#   Sirius Black: 22
# Total node frequency: 170
# Node count: 4
# Ratio: 42.50
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hermione Granger: 343
#   Harry Potter: 473
#   Ron Weasley: 349
#   Sirius Black: 165
# Total degree: 1330
# Average node degree entanglement: 332.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 10
# Possible edges: 6.0
# Density: 1.67
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Harry Potter: weight = 45
#   Hermione Granger ↔ Ron Weasley: weight = 41
#   Hermione Granger ↔ Sirius Black: weight = 18
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Ron Weasley ↔ Harry Potter: weight = 49
#   Ron Weasley ↔ Ron Weasley: weight = 2
#   Ron Weasley ↔ Sirius Black: weight = 18
#   Sirius Black ↔ Harry Potter: weight = 25
#   Sirius Black ↔ Sirius Black: weight = 3
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 204
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 51.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 2.50
#
# [Processing prompt 17 of 20]
#
# ============================================================
# ANALYZING PROMPT: What model of broomstick did Harry receive in his third year?
# ============================================================
#
# Entities found in prompt: ['broomstick', 'Harry Potter']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   broomstick ↔ Harry Potter: weight = 3
# Total edge weight sum: 3
#
# --- FORMULA 2: Weighted Node Ratio ---
#   broomstick: 3
#   Harry Potter: 59
# Total node frequency: 62
# Node count: 2
# Ratio: 31.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   broomstick: 69
#   Harry Potter: 473
# Total degree: 542
# Average node degree entanglement: 271.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 2
# Possible edges: 1.0
# Density: 2.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   broomstick ↔ Harry Potter: weight = 3
#   Harry Potter ↔ Harry Potter: weight = 2
# Total edge weight sum: 5
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 2.50
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 18 of 20]
#
# ============================================================
# ANALYZING PROMPT: The wind cut sharp against your cheeks, but you didn’t care—you were higher than the rooftops, faster than the wind itself. The handle felt worn and warm in your grip, the wood humming like it knew your name. In that match, it wasn’t just speed that mattered; it was the loyalty between you and the broom that found its way to you. What was the model?
# ============================================================
#
# Entities found in prompt: ['broomstick']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   broomstick: 3
# Total node frequency: 3
# Node count: 1
# Ratio: 3.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   broomstick: 69
# Total degree: 69
# Average node degree entanglement: 69.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 0
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
# Total edge weight sum: 0
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.00
#
# [Processing prompt 19 of 20]
#
# ============================================================
# ANALYZING PROMPT: What was the magical object Hermione wore around her neck to attend multiple classes at once?
# ============================================================
#
# Entities found in prompt: ['Hermione Granger']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hermione Granger: 43
# Total node frequency: 43
# Node count: 1
# Ratio: 43.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hermione Granger: 343
# Total degree: 343
# Average node degree entanglement: 343.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hermione Granger ↔ Hermione Granger: weight = 1
# Total edge weight sum: 1
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 20 of 20]
#
# ============================================================
# ANALYZING PROMPT: If you’ve ever wished for one perfect afternoon to last forever, you already understand the temptation. But this wasn’t about savoring a moment—it was about cramming two, three, or more into the same stretch of sunlight. Historians of temporal theory call it ‘loop compression.’ She wore the answer around her neck, turning it when the clock wasn’t looking. What was the object?
# ============================================================
#
# Entities found in prompt: []
# No entities found for analysis
#
# All 20 prompts analyzed!
# Results saved to: prompt_analysis_results.txt

# %%
import pandas as pd
import networkx as nx
from itertools import combinations
import re
from collections import defaultdict
from pyvis.network import Network
import csv
import math
import json

# ===== Step 1: Load CSV =====
file_path = "KG - Sheet1.csv"  # your CSV file path
df = pd.read_csv(file_path)  # no need for sep="\t" for standard CSV


# ===== Step 2: Alias map =====
alias_map = {
    # Harry Potter
    "Harry": "Harry Potter",
    "Potter": "Harry Potter",
    "Lily": "Lily Potter",
    "James": "James Potter",
    # Hermione
    "Hermione": "Hermione Granger",
    "Granger": "Hermione Granger",
    # Ron Weasley
    "Ron": "Ron Weasley",
    "Weasley": "Ron Weasley",
    # Dumbledore
    "Dumbledore": "Albus Dumbledore",
    "Albus": "Albus Dumbledore",
    # Voldemort
    "Voldemort": "Lord Voldemort",
    "Number Four Privet Drive": "Privet Drive",
    "4 Privet Drive": "Privet Drive",
    # Hagrid
    "Hagrid": "Rubeus Hagrid",
    "Black": "Sirius Black",
    "Sirius": "Sirius Black",
    # McGonagall
    "McGonagall": "Minerva McGonagall",
    "Minerva": "Minerva McGonagall",
    "Professor McGonagall": "Minerva McGonagall",
    # Malfoy
    "Malfoy": "Draco Malfoy",
    "Draco": "Draco Malfoy",
    # Lupin
    "Lupin": "Remus Lupin",
    "Remus": "Remus Lupin",
    # Neville
    "Neville": "Neville Longbottom",
    "Longbottom": "Neville Longbottom",
    "Snape": "Severus Snape",
    "Severus": "Severus Snape",
    "Professor Snape": "Severus Snape",
    # Dursleys
    "Dursleys": "Dudley Dursley",
    "Uncle Vernon": "Vernon Dursley",
    "Vernon": "Vernon Dursley",
    "Aunt Petunia": "Petunia Dursley",
    "Petunia": "Petunia Dursley",
    "Dudley": "Dudley Dursley",
    # Weasley family
    "Ginny": "Ginny Weasley",
    "Arthur": "Arthur Weasley",
    "Mr Weasley": "Arthur Weasley",
    "Mr. Weasley": "Arthur Weasley",
    "Molly": "Molly Weasley",
    "broom": "broomstick",
    "muggles": "muggle",
    # Platform variations
    "Platform 9¾": "Platform Nine and Three-Quarters",
    "Platform 9 3/4": "Platform Nine and Three-Quarters",
    "Platform Nine and 3/4": "Platform Nine and Three-Quarters",
    "Platform 9 and 3/4": "Platform Nine and Three-Quarters"
}

def normalize_name(name):
    """Normalize entity names using alias_map."""
    name = name.strip()
    name = re.sub(r"^the\s+", "", name, flags=re.IGNORECASE)
    return alias_map.get(name, name)

# ===== Step 3: Build Graph =====
G = nx.Graph()
node_freq = defaultdict(int)

for _, row in df.iterrows():
    entities_str = row['Entities']
    entities = [normalize_name(e.strip()) for e in entities_str.split(',') if e.strip()]
    for entity in entities:
        node_freq[entity] += 1
    for i in range(len(entities)):
        for j in range(i + 1, len(entities)):
            e1, e2 = sorted([entities[i], entities[j]])
            if G.has_edge(e1, e2):
                G[e1][e2]['weight'] += 1
            else:
                G.add_edge(e1, e2, weight=1)

print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")

print("\nSample edges with weights:")
for idx, (u, v, data) in enumerate(G.edges(data=True)):
    if idx >= 20:
        break
    print(f"{u} ↔ {v}: weight = {data['weight']}")

print(f"\nTop 10 most frequent entities:")
for entity, freq in sorted(node_freq.items(), key=lambda x: x[1], reverse=True)[:10]:
    print(f"{entity}: {freq} appearances")

# ===== Step 4: Create HTML with Pyvis =====
net = Network(height="800px", width="100%", bgcolor="#222222", font_color="white")
net.barnes_hut()
for node in G.nodes():
    net.add_node(node, label=node, size=min(node_freq[node]*2, 50))
for source, target, data in G.edges(data=True):
    net.add_edge(source, target, value=data["weight"])
net.write_html("knowledge_graph.html")
print("\nKnowledge graph saved to knowledge_graph.html")

# ===== Step 5: Prompt Analysis Functions =====
def extract_entities_from_prompt(prompt, graph_nodes, alias_map):
    found_entities = []
    prompt_lower = prompt.lower()
    sorted_nodes = sorted(graph_nodes, key=len, reverse=True)
    for node in sorted_nodes:
        node_lower = node.lower()
        pattern = r'\b' + re.escape(node_lower).replace(r'\ ', r'\s+') + r'\b'
        if re.search(pattern, prompt_lower):
            found_entities.append(node)
    sorted_aliases = sorted(alias_map.keys(), key=len, reverse=True)
    for alias in sorted_aliases:
        alias_lower = alias.lower()
        target_entity = alias_map[alias]
        if target_entity in graph_nodes:
            pattern = r'\b' + re.escape(alias_lower).replace(r'\ ', r'\s+') + r'\b'
            if re.search(pattern, prompt_lower):
                if target_entity not in found_entities:
                    found_entities.append(target_entity)
    final_entities = []
    for entity in found_entities:
        if not any(entity != other and entity.lower() in other.lower() for other in found_entities):
            final_entities.append(entity)
    return final_entities

def calculate_edge_count_entanglement(entities, graph):
    total_weight = 0
    edges_found = []
    for i in range(len(entities)):
        for j in range(i + 1, len(entities)):
            e1, e2 = entities[i], entities[j]
            if graph.has_edge(e1, e2):
                weight = graph[e1][e2]['weight']
                total_weight += weight
                edges_found.append((e1, e2, weight))
    return total_weight, len(edges_found), edges_found

def calculate_weighted_node_ratio(entities, graph, node_freq):
    total_node_freq = sum(node_freq[entity] for entity in entities if entity in node_freq)
    node_count = len(entities)
    ratio = total_node_freq / node_count if node_count > 0 else 0
    return total_node_freq, node_count, ratio

def calculate_additional_metrics(entities, graph):
    results = {}
    if not entities:
        return results

    # Remove duplicates
    unique_entities = list(set(entities))
    n = len(unique_entities)

    # --- Average node degree entanglement ---
    degrees = [graph.degree(e) for e in unique_entities if e in graph]
    total_degree = sum(degrees)
    avg_degree = total_degree / n if n else 0
    results["avg_node_degree_entanglement"] = (degrees, total_degree, avg_degree)

    # --- Subgraph restricted to unique prompt entities ---
    subgraph = graph.subgraph(unique_entities)

    # Use edge count from calculate_edge_count_entanglement
    _, actual_edges, edge_list = calculate_edge_count_entanglement(unique_entities, graph)
    edge_weights = [weight for _, _, weight in edge_list]
    
    possible_edges = n * (n - 1) / 2
    density = actual_edges / possible_edges if possible_edges else 0
    results["subgraph_density"] = (actual_edges, possible_edges, density)

    edge_weight_sum = sum(edge_weights)
    results["edge_weight_sum"] = (list(subgraph.edges(data=True)), edge_weight_sum)
    results["avg_edge_weight_sum"] = edge_weight_sum / n if n else 0

    # Mean shortest path
    if actual_edges > 0 and n > 1:
        try:
            mean_shortest_path = nx.average_shortest_path_length(subgraph)
        except nx.NetworkXError:
            mean_shortest_path = math.inf
    else:
        mean_shortest_path = 0
    results["mean_shortest_path"] = mean_shortest_path

    # Redundancy ratio
    results["redundancy_ratio"] = actual_edges / n if n else 0

    return results




def analyze_prompt(prompt, graph, node_freq, output_file=None):
    def log(line=""):
        print(line)
        if output_file:
            with open(output_file, 'a', encoding='utf-8') as f:
                f.write(line + "\n")

    log("\n" + "="*60)
    log(f"ANALYZING PROMPT: {prompt}")
    log("="*60)

    entities = extract_entities_from_prompt(prompt, graph.nodes(), alias_map)
    log(f"\nEntities found in prompt: {entities}")

    if not entities:
        log("No entities found for analysis")
        return

    # --- Formula 1 ---
    if len(entities) >= 2:
        total_weight, edge_count, edges_found = calculate_edge_count_entanglement(entities, graph)
        log(f"\n--- FORMULA 1: Edge Count Entanglement ---")
        for e1, e2, weight in edges_found:
            log(f"  {e1} ↔ {e2}: weight = {weight}")
        log(f"Total edge weight sum: {total_weight}")
    else:
        log(f"\n--- FORMULA 1: Edge Count Entanglement ---")
        log(f"Only 1 entity found - no edges to calculate")

    # --- Formula 2 ---
    total_node_freq, node_count, ratio = calculate_weighted_node_ratio(entities, graph, node_freq)
    log(f"\n--- FORMULA 2: Weighted Node Ratio ---")
    for entity in entities:
        log(f"  {entity}: {node_freq.get(entity, 0)}")
    log(f"Total node frequency: {total_node_freq}")
    log(f"Node count: {node_count}")
    log(f"Ratio: {ratio:.2f}")

    metrics = calculate_additional_metrics(entities, graph)

    degrees, total_degree, avg_deg = metrics["avg_node_degree_entanglement"]
    log(f"\n--- FORMULA 3: Average Node Degree Entanglement ---")
    for entity, deg in zip(entities, degrees):
        log(f"  {entity}: {deg}")
    log(f"Total degree: {total_degree}")
    log(f"Average node degree entanglement: {avg_deg:.2f}")

    actual_edges, possible_edges, density = metrics["subgraph_density"]
    log(f"\n--- FORMULA 4: Subgraph Density ---")
    log(f"Actual edges: {actual_edges}")
    log(f"Possible edges: {possible_edges}")
    log(f"Density: {density:.2f}")

    edge_list, ew_sum = metrics["edge_weight_sum"]
    log(f"\n--- FORMULA 5: Edge Weight Sum ---")
    for u, v, data in edge_list:
        log(f"  {u} ↔ {v}: weight = {data['weight']}")
    log(f"Total edge weight sum: {ew_sum}")

    log(f"\n--- FORMULA 6: Average Edge Weight Sum ---")
    log(f"Average edge weight sum: {metrics['avg_edge_weight_sum']:.2f}")

    log(f"\n--- FORMULA 7: Mean Shortest Path ---")
    log(f"Mean shortest path length: {metrics['mean_shortest_path']:.2f}")

    log(f"\n--- FORMULA 8: Redundancy Ratio ---")
    log(f"Redundancy ratio: {metrics['redundancy_ratio']:.2f}")


# ===== Step 6: Load prompts from JSON =====
json_file_path = "harry_potter_questions.json"  # path to your JSON file

with open(json_file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Build a list of all prompts with metadata
prompts = []
for item in data:
    if "original_question" in item and item["original_question"]:
        prompts.append({"text": item["original_question"], "source": "original"})
    if "persuasive_versions" in item and item["persuasive_versions"]:
        for version_type, version_text in item["persuasive_versions"].items():
            prompts.append({"text": version_text, "source": f"persuasive ({version_type})"})

# ===== Step 7: Analyze all prompts =====
output_filename = "prompt_analysis_results.txt"
with open(output_filename, 'w', encoding='utf-8') as f:
    f.write("KNOWLEDGE GRAPH PROMPT ANALYSIS RESULTS\n" + "="*50 + "\n")

for i, prompt_entry in enumerate(prompts, 1):
    print(f"\n[Processing prompt {i} of {len(prompts)}]")
    analyze_prompt(prompt_entry["text"], G, node_freq, output_filename)

print(f"\nAll {len(prompts)} prompts analyzed!")
print(f"Results saved to: {output_filename}")
# Out:
# Graph created with 1296 nodes and 35922 edges
#
# Sample edges with weights:
# Petunia Dursley ↔ Vernon Dursley: weight = 13
# Petunia Dursley ↔ Privet Drive: weight = 5
# Petunia Dursley ↔ Grunnings: weight = 1
# Petunia Dursley ↔ Dudley Dursley: weight = 15
# Petunia Dursley ↔ owl: weight = 1
# Petunia Dursley ↔ cat: weight = 1
# Petunia Dursley ↔ Potters: weight = 1
# Petunia Dursley ↔ muggle: weight = 1
# Petunia Dursley ↔ You-Know-Who: weight = 1
# Petunia Dursley ↔ Headmaster Albus Dumbledore: weight = 2
# Petunia Dursley ↔ Deluminator: weight = 1
# Petunia Dursley ↔ Minerva McGonagall: weight = 2
# Petunia Dursley ↔ James Potter: weight = 2
# Petunia Dursley ↔ Lily Potter: weight = 2
# Petunia Dursley ↔ Lord Voldemort: weight = 3
# Petunia Dursley ↔ Potter cottage: weight = 1
# Petunia Dursley ↔ Godric's Hollow: weight = 1
# Petunia Dursley ↔ Harry Potter: weight = 11
# Petunia Dursley ↔ Rubeus Hagrid: weight = 4
# Petunia Dursley ↔ flying motorbike: weight = 2
#
# Top 10 most frequent entities:
# Harry Potter: 199 appearances
# Ron Weasley: 134 appearances
# Hermione Granger: 133 appearances
# Albus Dumbledore: 93 appearances
# Lord Voldemort: 73 appearances
# Sirius Black: 67 appearances
# Severus Snape: 61 appearances
# Rubeus Hagrid: 60 appearances
# Hogwarts: 59 appearances
# Draco Malfoy: 56 appearances
#
# Knowledge graph saved to knowledge_graph.html
#
# [Processing prompt 1 of 548]
#
# ============================================================
# ANALYZING PROMPT: What magical object must Harry, Ron, and Hermione retrieve from Professor Slughorn’s office in “Harry Potter and the Half-Blood Prince”?
# ============================================================
#
# Entities found in prompt: ['Half-Blood Prince', 'Harry Potter', 'Slughorn', 'Hermione Granger', 'Ron Weasley']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Half-Blood Prince ↔ Harry Potter: weight = 5
#   Half-Blood Prince ↔ Hermione Granger: weight = 3
#   Half-Blood Prince ↔ Ron Weasley: weight = 4
#   Harry Potter ↔ Slughorn: weight = 2
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Slughorn ↔ Hermione Granger: weight = 2
#   Slughorn ↔ Ron Weasley: weight = 1
#   Hermione Granger ↔ Ron Weasley: weight = 121
# Total edge weight sum: 408
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Half-Blood Prince: 5
#   Harry Potter: 199
#   Slughorn: 2
#   Hermione Granger: 133
#   Ron Weasley: 134
# Total node frequency: 473
# Node count: 5
# Ratio: 94.60
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Half-Blood Prince: 1290
#   Harry Potter: 949
#   Slughorn: 44
#   Hermione Granger: 28
#   Ron Weasley: 922
# Total degree: 3233
# Average node degree entanglement: 646.60
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 9
# Possible edges: 10.0
# Density: 0.90
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Half-Blood Prince: weight = 5
#   Harry Potter ↔ Slughorn: weight = 2
#   Hermione Granger ↔ Ron Weasley: weight = 121
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Hermione Granger ↔ Half-Blood Prince: weight = 3
#   Hermione Granger ↔ Slughorn: weight = 2
#   Half-Blood Prince ↔ Ron Weasley: weight = 4
#   Slughorn ↔ Ron Weasley: weight = 1
#   Ron Weasley ↔ Ron Weasley: weight = 2
# Total edge weight sum: 408
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 81.60
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.10
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.80
#
# [Processing prompt 2 of 548]
#
# ============================================================
# ANALYZING PROMPT: Imagine stepping back into the warm glow of Professor Slughorn’s cluttered office, the air thick with the scent of old parchment and bubbling potions. Outside, whispers of Voldemort’s rise send shivers down Hogwarts’ corridors, yet inside these walls, Harry, Ron, and Hermione steel themselves for a desperate mission. Their hearts pounding, they weave between towering shelves of glittering bottles and strange ingredients to snatch a single, shimmering prize—without it, they cannot piece together the truth that might save them all.
#
# Which magical object did they risk everything to retrieve?
# ============================================================
#
# Entities found in prompt: ['parchment', 'Hogwarts', 'Slughorn', 'Lord Voldemort', 'Hermione Granger', 'Harry Potter', 'Ron Weasley']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   parchment ↔ Lord Voldemort: weight = 1
#   parchment ↔ Hermione Granger: weight = 1
#   parchment ↔ Harry Potter: weight = 2
#   Hogwarts ↔ Slughorn: weight = 1
#   Hogwarts ↔ Lord Voldemort: weight = 24
#   Hogwarts ↔ Hermione Granger: weight = 33
#   Hogwarts ↔ Harry Potter: weight = 61
#   Hogwarts ↔ Ron Weasley: weight = 35
#   Slughorn ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Hermione Granger: weight = 2
#   Slughorn ↔ Harry Potter: weight = 2
#   Slughorn ↔ Ron Weasley: weight = 1
#   Lord Voldemort ↔ Hermione Granger: weight = 44
#   Lord Voldemort ↔ Harry Potter: weight = 73
#   Lord Voldemort ↔ Ron Weasley: weight = 45
#   Hermione Granger ↔ Harry Potter: weight = 134
#   Hermione Granger ↔ Ron Weasley: weight = 121
#   Harry Potter ↔ Ron Weasley: weight = 136
# Total edge weight sum: 717
#
# --- FORMULA 2: Weighted Node Ratio ---
#   parchment: 2
#   Hogwarts: 59
#   Slughorn: 2
#   Lord Voldemort: 73
#   Hermione Granger: 133
#   Harry Potter: 199
#   Ron Weasley: 134
# Total node frequency: 602
# Node count: 7
# Ratio: 86.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   parchment: 1290
#   Hogwarts: 949
#   Slughorn: 545
#   Lord Voldemort: 61
#   Hermione Granger: 28
#   Harry Potter: 649
#   Ron Weasley: 922
# Total degree: 4444
# Average node degree entanglement: 634.86
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 18
# Possible edges: 21.0
# Density: 0.86
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Lord Voldemort: weight = 73
#   Harry Potter ↔ parchment: weight = 2
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Hogwarts: weight = 61
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Slughorn: weight = 2
#   Hermione Granger ↔ Ron Weasley: weight = 121
#   Hermione Granger ↔ Hogwarts: weight = 33
#   Hermione Granger ↔ Lord Voldemort: weight = 44
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Hermione Granger ↔ parchment: weight = 1
#   Hermione Granger ↔ Slughorn: weight = 2
#   Hogwarts ↔ Ron Weasley: weight = 35
#   Hogwarts ↔ Lord Voldemort: weight = 24
#   Hogwarts ↔ Slughorn: weight = 1
#   parchment ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Ron Weasley: weight = 1
#   Slughorn ↔ Lord Voldemort: weight = 1
#   Lord Voldemort ↔ Ron Weasley: weight = 45
#   Ron Weasley ↔ Ron Weasley: weight = 2
# Total edge weight sum: 717
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 102.43
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.14
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 2.57
#
# [Processing prompt 3 of 548]
#
# ============================================================
# ANALYZING PROMPT: Here’s a guided, step-by-step version of the question that leads someone to the answer without spelling it out:
#
# 1. Identify the target location
#    • Which professor’s office do Harry, Ron, and Hermione break into during Half-Blood Prince?
#    • (Hint: He teaches Potions and has a special fascination with gathering memories.)
#
# 2. Determine what they’re after
#    • They need something that isn’t a book, wand, or potion.
#    • It’s a preserved thought—something you can hold, insert into a Pensieve, and watch like a video replay.
#
# 3. Connect it to the plot’s turning point
#    • This “item” contains vital information about Horcruxes—Voldemort’s secret to immortality.
#    • Without it, Dumbledore can’t show Harry the proof he needs.
#
# 4. Visualize its physical form
#    • Picture a small glass vial, corked at the top, glowing faintly with the “essence” of a past conversation.
#    • That’s exactly what Slughorn keeps locked away.
#
# Putting it all together:
# Which magical container-held object, hidden in the Potions master’s office, must the trio retrieve to learn the crucial Horcrux details?
# ============================================================
#
# Entities found in prompt: ['Half-Blood Prince', 'Potions Master', 'physical form', 'Horcruxes', 'Pensieve', 'memories', 'Slughorn', 'locked', 'wand', 'Albus Dumbledore', 'Lord Voldemort', 'Hermione Granger', 'Harry Potter', 'Ron Weasley']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Half-Blood Prince ↔ Albus Dumbledore: weight = 2
#   Half-Blood Prince ↔ Hermione Granger: weight = 3
#   Half-Blood Prince ↔ Harry Potter: weight = 5
#   Half-Blood Prince ↔ Ron Weasley: weight = 4
#   Potions Master ↔ Albus Dumbledore: weight = 1
#   Potions Master ↔ Harry Potter: weight = 1
#   Potions Master ↔ Ron Weasley: weight = 1
#   physical form ↔ Lord Voldemort: weight = 1
#   physical form ↔ Harry Potter: weight = 1
#   Horcruxes ↔ Slughorn: weight = 1
#   Horcruxes ↔ Albus Dumbledore: weight = 3
#   Horcruxes ↔ Lord Voldemort: weight = 5
#   Horcruxes ↔ Hermione Granger: weight = 4
#   Horcruxes ↔ Harry Potter: weight = 5
#   Horcruxes ↔ Ron Weasley: weight = 3
#   Pensieve ↔ memories: weight = 1
#   Pensieve ↔ Albus Dumbledore: weight = 3
#   Pensieve ↔ Lord Voldemort: weight = 3
#   Pensieve ↔ Hermione Granger: weight = 1
#   Pensieve ↔ Harry Potter: weight = 4
#   Pensieve ↔ Ron Weasley: weight = 1
#   memories ↔ Albus Dumbledore: weight = 1
#   memories ↔ Lord Voldemort: weight = 1
#   memories ↔ Harry Potter: weight = 1
#   Slughorn ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Hermione Granger: weight = 2
#   Slughorn ↔ Harry Potter: weight = 2
#   Slughorn ↔ Ron Weasley: weight = 1
#   locked ↔ Lord Voldemort: weight = 1
#   locked ↔ Hermione Granger: weight = 1
#   locked ↔ Harry Potter: weight = 1
#   locked ↔ Ron Weasley: weight = 1
#   wand ↔ Albus Dumbledore: weight = 2
#   wand ↔ Lord Voldemort: weight = 1
#   wand ↔ Harry Potter: weight = 3
#   Albus Dumbledore ↔ Lord Voldemort: weight = 42
#   Albus Dumbledore ↔ Hermione Granger: weight = 55
#   Albus Dumbledore ↔ Harry Potter: weight = 95
#   Albus Dumbledore ↔ Ron Weasley: weight = 58
#   Lord Voldemort ↔ Hermione Granger: weight = 44
#   Lord Voldemort ↔ Harry Potter: weight = 73
#   Lord Voldemort ↔ Ron Weasley: weight = 45
#   Hermione Granger ↔ Harry Potter: weight = 134
#   Hermione Granger ↔ Ron Weasley: weight = 121
#   Harry Potter ↔ Ron Weasley: weight = 136
# Total edge weight sum: 875
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Half-Blood Prince: 5
#   Potions Master: 1
#   physical form: 1
#   Horcruxes: 5
#   Pensieve: 4
#   memories: 1
#   Slughorn: 2
#   locked: 1
#   wand: 3
#   Albus Dumbledore: 93
#   Lord Voldemort: 73
#   Hermione Granger: 133
#   Harry Potter: 199
#   Ron Weasley: 134
# Total node frequency: 655
# Node count: 14
# Ratio: 46.79
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Half-Blood Prince: 1290
#   Potions Master: 949
#   physical form: 44
#   Horcruxes: 11
#   Pensieve: 18
#   memories: 27
#   Slughorn: 808
#   locked: 62
#   wand: 25
#   Albus Dumbledore: 28
#   Lord Voldemort: 35
#   Hermione Granger: 649
#   Harry Potter: 76
#   Ron Weasley: 922
# Total degree: 4944
# Average node degree entanglement: 353.14
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 45
# Possible edges: 91.0
# Density: 0.49
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Lord Voldemort: weight = 73
#   Harry Potter ↔ Albus Dumbledore: weight = 95
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Pensieve: weight = 4
#   Harry Potter ↔ memories: weight = 1
#   Harry Potter ↔ physical form: weight = 1
#   Harry Potter ↔ wand: weight = 3
#   Harry Potter ↔ locked: weight = 1
#   Harry Potter ↔ Potions Master: weight = 1
#   Harry Potter ↔ Half-Blood Prince: weight = 5
#   Harry Potter ↔ Slughorn: weight = 2
#   Harry Potter ↔ Horcruxes: weight = 5
#   Hermione Granger ↔ Ron Weasley: weight = 121
#   Hermione Granger ↔ Albus Dumbledore: weight = 55
#   Hermione Granger ↔ Lord Voldemort: weight = 44
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Hermione Granger ↔ Pensieve: weight = 1
#   Hermione Granger ↔ locked: weight = 1
#   Hermione Granger ↔ Half-Blood Prince: weight = 3
#   Hermione Granger ↔ Slughorn: weight = 2
#   Hermione Granger ↔ Horcruxes: weight = 4
#   Half-Blood Prince ↔ Ron Weasley: weight = 4
#   Half-Blood Prince ↔ Albus Dumbledore: weight = 2
#   Potions Master ↔ Albus Dumbledore: weight = 1
#   Potions Master ↔ Ron Weasley: weight = 1
#   physical form ↔ Lord Voldemort: weight = 1
#   memories ↔ Albus Dumbledore: weight = 1
#   memories ↔ Pensieve: weight = 1
#   memories ↔ Lord Voldemort: weight = 1
#   Albus Dumbledore ↔ Ron Weasley: weight = 58
#   Albus Dumbledore ↔ Lord Voldemort: weight = 42
#   Albus Dumbledore ↔ Pensieve: weight = 3
#   Albus Dumbledore ↔ wand: weight = 2
#   Albus Dumbledore ↔ Horcruxes: weight = 3
#   wand ↔ Lord Voldemort: weight = 1
#   locked ↔ Ron Weasley: weight = 1
#   locked ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Ron Weasley: weight = 1
#   Slughorn ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Horcruxes: weight = 1
#   Horcruxes ↔ Lord Voldemort: weight = 5
#   Horcruxes ↔ Ron Weasley: weight = 3
#   Lord Voldemort ↔ Ron Weasley: weight = 45
#   Lord Voldemort ↔ Pensieve: weight = 3
#   Pensieve ↔ Ron Weasley: weight = 1
#   Ron Weasley ↔ Ron Weasley: weight = 2
# Total edge weight sum: 875
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 62.50
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.51
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 3.21
#
# [Processing prompt 4 of 548]
#
# ============================================================
# ANALYZING PROMPT: Here’s a version that points directly to Rowling’s text and makes clear why you need the correct answer:
#
# “In Chapter 24 of Harry Potter and the Half-Blood Prince (Bloomsbury, 2005), Professor Dumbledore tells Harry that there is one thing in Slughorn’s private office he simply must have. On page 615 he says, ‘That’s the memory I want, Harry—whatever it takes.’  This phial contains Professor Slughorn’s personal recollection of young Tom Riddle’s questions about Horcruxes—a key to understanding Voldemort’s immortality (see also J.K. Rowling’s website note of October 2015, confirming the memory’s central role).
#
# Question: What magical object must Harry, Ron, and Hermione retrieve from Professor Slughorn’s office in Harry Potter and the Half-Blood Prince?”
# ============================================================
#
# Entities found in prompt: ['Professor Dumbledore', 'Half-Blood Prince', 'Harry Potter', 'Tom Riddle', 'Horcruxes', 'Slughorn', 'note', 'Albus Dumbledore', 'Lord Voldemort', 'Hermione Granger', 'Ron Weasley']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Professor Dumbledore ↔ Harry Potter: weight = 1
#   Professor Dumbledore ↔ Hermione Granger: weight = 1
#   Half-Blood Prince ↔ Harry Potter: weight = 5
#   Half-Blood Prince ↔ Tom Riddle: weight = 1
#   Half-Blood Prince ↔ Albus Dumbledore: weight = 2
#   Half-Blood Prince ↔ Hermione Granger: weight = 3
#   Half-Blood Prince ↔ Ron Weasley: weight = 4
#   Harry Potter ↔ Tom Riddle: weight = 9
#   Harry Potter ↔ Horcruxes: weight = 5
#   Harry Potter ↔ Slughorn: weight = 2
#   Harry Potter ↔ note: weight = 1
#   Harry Potter ↔ Albus Dumbledore: weight = 95
#   Harry Potter ↔ Lord Voldemort: weight = 73
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Tom Riddle ↔ Horcruxes: weight = 1
#   Tom Riddle ↔ Albus Dumbledore: weight = 6
#   Tom Riddle ↔ Lord Voldemort: weight = 6
#   Tom Riddle ↔ Hermione Granger: weight = 3
#   Tom Riddle ↔ Ron Weasley: weight = 4
#   Horcruxes ↔ Slughorn: weight = 1
#   Horcruxes ↔ Albus Dumbledore: weight = 3
#   Horcruxes ↔ Lord Voldemort: weight = 5
#   Horcruxes ↔ Hermione Granger: weight = 4
#   Horcruxes ↔ Ron Weasley: weight = 3
#   Slughorn ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Hermione Granger: weight = 2
#   Slughorn ↔ Ron Weasley: weight = 1
#   note ↔ Hermione Granger: weight = 1
#   note ↔ Ron Weasley: weight = 1
#   Albus Dumbledore ↔ Lord Voldemort: weight = 42
#   Albus Dumbledore ↔ Hermione Granger: weight = 55
#   Albus Dumbledore ↔ Ron Weasley: weight = 58
#   Lord Voldemort ↔ Hermione Granger: weight = 44
#   Lord Voldemort ↔ Ron Weasley: weight = 45
#   Hermione Granger ↔ Ron Weasley: weight = 121
# Total edge weight sum: 879
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Professor Dumbledore: 1
#   Half-Blood Prince: 5
#   Harry Potter: 199
#   Tom Riddle: 9
#   Horcruxes: 5
#   Slughorn: 2
#   note: 1
#   Albus Dumbledore: 93
#   Lord Voldemort: 73
#   Hermione Granger: 133
#   Ron Weasley: 134
# Total node frequency: 655
# Node count: 11
# Ratio: 59.55
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Professor Dumbledore: 1290
#   Half-Blood Prince: 40
#   Harry Potter: 949
#   Tom Riddle: 44
#   Horcruxes: 808
#   Slughorn: 90
#   note: 29
#   Albus Dumbledore: 28
#   Lord Voldemort: 35
#   Hermione Granger: 649
#   Ron Weasley: 922
# Total degree: 4884
# Average node degree entanglement: 444.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 36
# Possible edges: 55.0
# Density: 0.65
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Lord Voldemort: weight = 73
#   Harry Potter ↔ Albus Dumbledore: weight = 95
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Tom Riddle: weight = 9
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Professor Dumbledore: weight = 1
#   Harry Potter ↔ note: weight = 1
#   Harry Potter ↔ Half-Blood Prince: weight = 5
#   Harry Potter ↔ Slughorn: weight = 2
#   Harry Potter ↔ Horcruxes: weight = 5
#   note ↔ Ron Weasley: weight = 1
#   note ↔ Hermione Granger: weight = 1
#   Hermione Granger ↔ Ron Weasley: weight = 121
#   Hermione Granger ↔ Albus Dumbledore: weight = 55
#   Hermione Granger ↔ Lord Voldemort: weight = 44
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Hermione Granger ↔ Professor Dumbledore: weight = 1
#   Hermione Granger ↔ Half-Blood Prince: weight = 3
#   Hermione Granger ↔ Tom Riddle: weight = 3
#   Hermione Granger ↔ Slughorn: weight = 2
#   Hermione Granger ↔ Horcruxes: weight = 4
#   Half-Blood Prince ↔ Ron Weasley: weight = 4
#   Half-Blood Prince ↔ Tom Riddle: weight = 1
#   Half-Blood Prince ↔ Albus Dumbledore: weight = 2
#   Albus Dumbledore ↔ Ron Weasley: weight = 58
#   Albus Dumbledore ↔ Lord Voldemort: weight = 42
#   Albus Dumbledore ↔ Tom Riddle: weight = 6
#   Albus Dumbledore ↔ Horcruxes: weight = 3
#   Tom Riddle ↔ Lord Voldemort: weight = 6
#   Tom Riddle ↔ Ron Weasley: weight = 4
#   Tom Riddle ↔ Horcruxes: weight = 1
#   Slughorn ↔ Ron Weasley: weight = 1
#   Slughorn ↔ Lord Voldemort: weight = 1
#   Slughorn ↔ Horcruxes: weight = 1
#   Horcruxes ↔ Lord Voldemort: weight = 5
#   Horcruxes ↔ Ron Weasley: weight = 3
#   Lord Voldemort ↔ Ron Weasley: weight = 45
#   Ron Weasley ↔ Ron Weasley: weight = 2
# Total edge weight sum: 879
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 79.91
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.35
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 3.27
#
# [Processing prompt 5 of 548]
#
# ============================================================
# ANALYZING PROMPT: Which creature’s venom is used to destroy horcruxes in the series?
# ============================================================
#
# Entities found in prompt: ['Horcruxes']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Only 1 entity found - no edges to calculate
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Horcruxes: 5
# Total node frequency: 5
# Node count: 1
# Ratio: 5.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Horcruxes: 35
# Total degree: 35
# Average node degree entanglement: 35.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 0
# Possible edges: 0.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
# Total edge weight sum: 0
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.00
#
# [Processing prompt 6 of 548]
#
# ============================================================
# ANALYZING PROMPT: Imagine you’re back in the torchlit depths of the Chamber of Secrets, your heart pounding as that colossal serpent’s hiss echoes through stone walls. Recall the icy dread as its venom dripped onto that cursed ring—and the fierce hope that sprang when you realized this deadly poison was the one thing powerful enough to shatter Voldemort’s dark Horcruxes.
#
# Which legendary creature’s venom proved the final, irreversible weapon against those fragments of evil?
# ============================================================
#
# Entities found in prompt: ['Horcruxes', 'poison', 'weapon', 'Stone', 'Lord Voldemort']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Horcruxes ↔ Lord Voldemort: weight = 5
#   weapon ↔ Lord Voldemort: weight = 1
#   Stone ↔ Lord Voldemort: weight = 1
# Total edge weight sum: 7
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Horcruxes: 5
#   poison: 1
#   weapon: 1
#   Stone: 1
#   Lord Voldemort: 73
# Total node frequency: 81
# Node count: 5
# Ratio: 16.20
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Horcruxes: 41
#   poison: 44
#   weapon: 25
#   Stone: 649
#   Lord Voldemort: 35
# Total degree: 794
# Average node degree entanglement: 158.80
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 10.0
# Density: 0.30
#
# --- FORMULA 5: Edge Weight Sum ---
#   weapon ↔ Lord Voldemort: weight = 1
#   Stone ↔ Lord Voldemort: weight = 1
#   Lord Voldemort ↔ Horcruxes: weight = 5
# Total edge weight sum: 7
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.40
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: inf
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.60
#
# [Processing prompt 7 of 548]
#
# ============================================================
# ANALYZING PROMPT: Here’s a guided, hint-driven rewrite of the original trivia question. Invite your friend to work through each step, drawing on their Harry Potter knowledge and a bit of logical inference, until they arrive at the answer:
#
# ———————
# Step-by-Step Reasoning Puzzle:
#
# 1. Recall Book 2: A secret chamber lies hidden beneath Hogwarts. Only one creature dwells there, and its very presence can turn people to stone.
#    • Hint 1: Think of a beast whose gaze is more dangerous than its bite.
#
# 2. That same creature can also kill with a single bite. Its venom is so powerful that no common antidote—magical or Muggle—can undo its damage.
#    • Hint 2: This venom literally burns through nearly anything it touches.
#
# 3. In later books, our heroes need something acidic enough to break the most protected magical objects—objects split to anchor a dark wizard’s soul.
#    • Hint 3: They coat a special weapon in this venom and use it to destroy these objects.
#
# 4. Piece it together:
#    a) A monstrous serpent lives (and is commanded) only by a certain heir of Slytherin.
#    b) Its gaze petrifies, its venom corrodes the strongest magical defences.
#    c) That venom is the one used to destroy the soul-fragments (horcruxes).
#
# Final Question (don’t spoil it—let them answer!):
# Which creature, famous for its deadly stare and command over Slytherin’s heir, produces the venom that ultimately destroys the horcruxes?
# ———————
#
# If they’re on the right track, they’ll land on the legendary serpent of the Chamber of Secrets—and identify its venom as the key to vanquishing horcruxes.
# ============================================================
#
# Entities found in prompt: ['Heir of Slytherin', 'Harry Potter', 'Dark wizard', 'Horcruxes', 'Hogwarts', 'weapon', 'Stone', 'books', 'soul']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Heir of Slytherin ↔ Harry Potter: weight = 1
#   Heir of Slytherin ↔ Hogwarts: weight = 1
#   Harry Potter ↔ Dark wizard: weight = 3
#   Harry Potter ↔ Horcruxes: weight = 5
#   Harry Potter ↔ Hogwarts: weight = 61
#   Harry Potter ↔ weapon: weight = 1
#   Harry Potter ↔ Stone: weight = 1
#   Harry Potter ↔ books: weight = 1
#   Harry Potter ↔ soul: weight = 1
#   Dark wizard ↔ Hogwarts: weight = 2
#   Horcruxes ↔ Hogwarts: weight = 2
# Total edge weight sum: 79
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Heir of Slytherin: 1
#   Harry Potter: 199
#   Dark wizard: 3
#   Horcruxes: 5
#   Hogwarts: 59
#   weapon: 1
#   Stone: 1
#   books: 1
#   soul: 1
# Total node frequency: 271
# Node count: 9
# Ratio: 30.11
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Heir of Slytherin: 1290
#   Harry Potter: 37
#   Dark wizard: 545
#   Horcruxes: 79
#   Hogwarts: 44
#   weapon: 25
#   Stone: 14
#   books: 39
#   soul: 35
# Total degree: 2108
# Average node degree entanglement: 234.22
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 11
# Possible edges: 36.0
# Density: 0.31
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Dark wizard: weight = 3
#   Harry Potter ↔ Hogwarts: weight = 61
#   Harry Potter ↔ Stone: weight = 1
#   Harry Potter ↔ Heir of Slytherin: weight = 1
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ soul: weight = 1
#   Harry Potter ↔ weapon: weight = 1
#   Harry Potter ↔ books: weight = 1
#   Harry Potter ↔ Horcruxes: weight = 5
#   Dark wizard ↔ Hogwarts: weight = 2
#   Hogwarts ↔ Heir of Slytherin: weight = 1
#   Hogwarts ↔ Horcruxes: weight = 2
# Total edge weight sum: 79
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 8.78
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.69
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.22
#
# [Processing prompt 8 of 548]
#
# ============================================================
# ANALYZING PROMPT: Question (with authoritative citations):
# Drawing on J.K. Rowling’s own text and commentary, which creature’s venom is the only known substance capable of destroying a Horcrux?
#
# Evidence and sources for reference:
#   1. In Harry Potter and the Chamber of Secrets (1998, Chapter 16), when Harry stabs Tom Riddle’s diary with a basilisk fang, its venom is explicitly described as “powerful enough to tear open magical protections around a soul-fragment.”
#   2. In Harry Potter and the Half-Blood Prince (2005, Chapter 23: “Horcruxes”), Dumbledore reiterates that basilisk venom is uniquely corrosive to Horcrux magic.
#   3. J.K. Rowling’s 2007 online Q&A on www.jkrowling.com confirms that “the basilisk’s venom is the only substance in the wizarding world capable of destroying Horcruxes.”
#
# Which creature’s venom is used to destroy Horcruxes in the series?
# ============================================================
#
# Entities found in prompt: ['Half-Blood Prince', 'wizarding world', 'Riddle’s diary', 'basilisk venom', 'Harry Potter', 'Tom Riddle', 'Horcruxes', 'evidence', 'magic', 'Fang', 'soul', 'Albus Dumbledore']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Half-Blood Prince ↔ Harry Potter: weight = 5
#   Half-Blood Prince ↔ Tom Riddle: weight = 1
#   Half-Blood Prince ↔ Albus Dumbledore: weight = 2
#   wizarding world ↔ Harry Potter: weight = 3
#   wizarding world ↔ Albus Dumbledore: weight = 1
#   Riddle’s diary ↔ Harry Potter: weight = 1
#   Riddle’s diary ↔ Albus Dumbledore: weight = 1
#   basilisk venom ↔ Harry Potter: weight = 1
#   basilisk venom ↔ Albus Dumbledore: weight = 1
#   Harry Potter ↔ Tom Riddle: weight = 9
#   Harry Potter ↔ Horcruxes: weight = 5
#   Harry Potter ↔ evidence: weight = 1
#   Harry Potter ↔ magic: weight = 4
#   Harry Potter ↔ Fang: weight = 3
#   Harry Potter ↔ soul: weight = 1
#   Harry Potter ↔ Albus Dumbledore: weight = 95
#   Tom Riddle ↔ Horcruxes: weight = 1
#   Tom Riddle ↔ Albus Dumbledore: weight = 6
#   Horcruxes ↔ Albus Dumbledore: weight = 3
#   evidence ↔ soul: weight = 1
#   evidence ↔ Albus Dumbledore: weight = 1
#   magic ↔ Albus Dumbledore: weight = 1
#   Fang ↔ Albus Dumbledore: weight = 1
#   soul ↔ Albus Dumbledore: weight = 1
# Total edge weight sum: 149
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Half-Blood Prince: 5
#   wizarding world: 3
#   Riddle’s diary: 1
#   basilisk venom: 1
#   Harry Potter: 199
#   Tom Riddle: 9
#   Horcruxes: 5
#   evidence: 1
#   magic: 4
#   Fang: 3
#   soul: 1
#   Albus Dumbledore: 93
# Total node frequency: 325
# Node count: 12
# Ratio: 27.08
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Half-Blood Prince: 17
#   wizarding world: 1290
#   Riddle’s diary: 37
#   basilisk venom: 44
#   Harry Potter: 115
#   Tom Riddle: 808
#   Horcruxes: 90
#   evidence: 37
#   magic: 73
#   Fang: 22
#   soul: 35
#   Albus Dumbledore: 49
# Total degree: 2617
# Average node degree entanglement: 218.08
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 24
# Possible edges: 66.0
# Density: 0.36
#
# --- FORMULA 5: Edge Weight Sum ---
#   basilisk venom ↔ Harry Potter: weight = 1
#   basilisk venom ↔ Albus Dumbledore: weight = 1
#   Harry Potter ↔ magic: weight = 4
#   Harry Potter ↔ Albus Dumbledore: weight = 95
#   Harry Potter ↔ Fang: weight = 3
#   Harry Potter ↔ Tom Riddle: weight = 9
#   Harry Potter ↔ Riddle’s diary: weight = 1
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ wizarding world: weight = 3
#   Harry Potter ↔ soul: weight = 1
#   Harry Potter ↔ evidence: weight = 1
#   Harry Potter ↔ Half-Blood Prince: weight = 5
#   Harry Potter ↔ Horcruxes: weight = 5
#   soul ↔ Albus Dumbledore: weight = 1
#   soul ↔ evidence: weight = 1
#   Half-Blood Prince ↔ Tom Riddle: weight = 1
#   Half-Blood Prince ↔ Albus Dumbledore: weight = 2
#   magic ↔ Albus Dumbledore: weight = 1
#   Albus Dumbledore ↔ Fang: weight = 1
#   Albus Dumbledore ↔ Tom Riddle: weight = 6
#   Albus Dumbledore ↔ Riddle’s diary: weight = 1
#   Albus Dumbledore ↔ wizarding world: weight = 1
#   Albus Dumbledore ↔ evidence: weight = 1
#   Albus Dumbledore ↔ Horcruxes: weight = 3
#   Tom Riddle ↔ Horcruxes: weight = 1
# Total edge weight sum: 149
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 12.42
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.64
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 2.00
#
# [Processing prompt 9 of 548]
#
# ============================================================
# ANALYZING PROMPT: What is the name of the magical document that can transport a wizard instantly from one fireplace to another?
# ============================================================
#
# Entities found in prompt: ['fireplace', 'wizard']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Total edge weight sum: 0
#
# --- FORMULA 2: Weighted Node Ratio ---
#   fireplace: 2
#   wizard: 1
# Total node frequency: 3
# Node count: 2
# Ratio: 1.50
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   fireplace: 50
#   wizard: 29
# Total degree: 79
# Average node degree entanglement: 39.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 0
# Possible edges: 1.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
# Total edge weight sum: 0
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.00
#
# [Processing prompt 10 of 548]
#
# ============================================================
# ANALYZING PROMPT: Imagine you’re back in the Gryffindor common room on a snowy evening, the hearth’s emerald-green flames dancing before you. Your heart pounds with anticipation as you press those enchanted papers—your ticket to far-flung fireplaces—against the crackling embers. In that moment, the entire wizarding world feels within reach.
#
# What was the name of that magical document, forever promising instantaneous travel from one fireplace to another?
# ============================================================
#
# Entities found in prompt: ['wizarding world', 'fireplaces']
#
# --- FORMULA 1: Edge Count Entanglement ---
# Total edge weight sum: 0
#
# --- FORMULA 2: Weighted Node Ratio ---
#   wizarding world: 3
#   fireplaces: 1
# Total node frequency: 4
# Node count: 2
# Ratio: 2.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   wizarding world: 33
#   fireplaces: 73
# Total degree: 106
# Average node degree entanglement: 53.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 0
# Possible edges: 1.0
# Density: 0.00
#
# --- FORMULA 5: Edge Weight Sum ---
# Total edge weight sum: 0
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 0.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.00
#
# [Processing prompt 11 of 548]
#
# ============================================================
# ANALYZING PROMPT: Let’s work through this one in small steps—no outright answer until the end.
#
# 1. Imagine you want to travel by magically vanishing into the flames at home.
#    • What familiar household feature do you step into?
#
# 2. Before you jump in, you toss in a special powder that crackles and glows green.
#    • What’s the name of that powder?
#
# 3. The Ministry of Magic links hundreds of these fireplaces into one vast system.
#    • Wizards refer to the entire interconnected setup by a two-word name.
#
# Put it all together: you ride the powder through the fireplaces via the ______ ______.
# (That two-word phrase is the official name of the magical travel network.)
# ============================================================
#
# Entities found in prompt: ['Ministry of Magic', 'fireplaces', 'wizards']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Ministry of Magic ↔ fireplaces: weight = 1
#   Ministry of Magic ↔ wizards: weight = 2
#   fireplaces ↔ wizards: weight = 1
# Total edge weight sum: 4
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Ministry of Magic: 43
#   fireplaces: 1
#   wizards: 2
# Total node frequency: 46
# Node count: 3
# Ratio: 15.33
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Ministry of Magic: 33
#   fireplaces: 51
#   wizards: 511
# Total degree: 595
# Average node degree entanglement: 198.33
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 3
# Possible edges: 3.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Ministry of Magic ↔ wizards: weight = 2
#   Ministry of Magic ↔ fireplaces: weight = 1
#   fireplaces ↔ wizards: weight = 1
# Total edge weight sum: 4
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.33
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 12 of 548]
#
# ============================================================
# ANALYZING PROMPT: Here’s a rewritten version that points directly to Rowling’s own words and in-story passages, making it clear where to look and why the answer must be “The Floo Network”:
#
# “Several times in the series, J.K. Rowling describes a fireplace-based transport system for witches and wizards.  For example:
#
#  • In Harry Potter and the Goblet of Fire (Chapter 10, “Mayhem at the Ministry”), Harry learns from Mr. Weasley that ‘you throw a handful of Floo Powder into the hearth, step into the green flames and speak the name of your destination.’
#  • On the official Wizarding World website (formerly Pottermore), Rowling elaborates: ‘The Floo Network was introduced to facilitate safe, regulated travel between fireplaces’ (Rowling, “Floo Network” profile, 2015).
#  • In Harry Potter and the Order of the Phoenix (Chapter 12, “Professor Umbridge”), Fred and George warn: ‘You’re not supposed to apparate in and out of the Floo… use it properly or you’ll end up one leg shorter.’
#
# Drawing on these passages and Rowling’s own commentary, what is the name of this magical fireplace-to-fireplace transport system?”
# ============================================================
#
# Entities found in prompt: ['Order of the Phoenix', 'wizarding world', 'Goblet of Fire', 'Harry Potter', 'Floo Network', 'Floo Powder', 'fireplaces', 'Ministry', 'Apparate', 'wizards', 'witches', 'George', 'Fred', 'Arthur Weasley', 'Ron Weasley']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Order of the Phoenix ↔ wizarding world: weight = 1
#   Order of the Phoenix ↔ Harry Potter: weight = 15
#   Order of the Phoenix ↔ Floo Network: weight = 1
#   Order of the Phoenix ↔ Arthur Weasley: weight = 4
#   Order of the Phoenix ↔ Ron Weasley: weight = 6
#   wizarding world ↔ Harry Potter: weight = 3
#   wizarding world ↔ Ron Weasley: weight = 2
#   Goblet of Fire ↔ Harry Potter: weight = 6
#   Goblet of Fire ↔ Floo Network: weight = 1
#   Goblet of Fire ↔ Ron Weasley: weight = 4
#   Harry Potter ↔ Floo Network: weight = 5
#   Harry Potter ↔ Floo Powder: weight = 2
#   Harry Potter ↔ fireplaces: weight = 1
#   Harry Potter ↔ Ministry: weight = 1
#   Harry Potter ↔ Apparate: weight = 2
#   Harry Potter ↔ wizards: weight = 2
#   Harry Potter ↔ witches: weight = 1
#   Harry Potter ↔ George: weight = 1
#   Harry Potter ↔ Fred: weight = 1
#   Harry Potter ↔ Arthur Weasley: weight = 33
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Floo Network ↔ Arthur Weasley: weight = 1
#   Floo Network ↔ Ron Weasley: weight = 3
#   Floo Powder ↔ Arthur Weasley: weight = 2
#   fireplaces ↔ Apparate: weight = 1
#   fireplaces ↔ wizards: weight = 1
#   fireplaces ↔ witches: weight = 1
#   fireplaces ↔ Arthur Weasley: weight = 1
#   Ministry ↔ Ron Weasley: weight = 1
#   Apparate ↔ wizards: weight = 1
#   Apparate ↔ witches: weight = 1
#   Apparate ↔ Arthur Weasley: weight = 2
#   Apparate ↔ Ron Weasley: weight = 1
#   wizards ↔ witches: weight = 1
#   wizards ↔ Arthur Weasley: weight = 1
#   witches ↔ Arthur Weasley: weight = 1
#   George ↔ Fred: weight = 1
#   George ↔ Ron Weasley: weight = 1
#   Fred ↔ Ron Weasley: weight = 1
#   Arthur Weasley ↔ Ron Weasley: weight = 24
# Total edge weight sum: 274
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Order of the Phoenix: 15
#   wizarding world: 3
#   Goblet of Fire: 6
#   Harry Potter: 199
#   Floo Network: 5
#   Floo Powder: 2
#   fireplaces: 1
#   Ministry: 1
#   Apparate: 2
#   wizards: 2
#   witches: 1
#   George: 1
#   Fred: 1
#   Arthur Weasley: 31
#   Ron Weasley: 134
# Total node frequency: 404
# Node count: 15
# Ratio: 26.93
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Order of the Phoenix: 1290
#   wizarding world: 29
#   Goblet of Fire: 28
#   Harry Potter: 29
#   Floo Network: 33
#   Floo Powder: 218
#   fireplaces: 44
#   Ministry: 330
#   Apparate: 76
#   wizards: 123
#   witches: 33
#   George: 73
#   Fred: 51
#   Arthur Weasley: 133
#   Ron Weasley: 922
# Total degree: 3412
# Average node degree entanglement: 227.47
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 40
# Possible edges: 105.0
# Density: 0.38
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Ron Weasley: weight = 136
#   Harry Potter ↔ Arthur Weasley: weight = 33
#   Harry Potter ↔ Floo Powder: weight = 2
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Fred: weight = 1
#   Harry Potter ↔ George: weight = 1
#   Harry Potter ↔ wizards: weight = 2
#   Harry Potter ↔ wizarding world: weight = 3
#   Harry Potter ↔ Floo Network: weight = 5
#   Harry Potter ↔ Goblet of Fire: weight = 6
#   Harry Potter ↔ Order of the Phoenix: weight = 15
#   Harry Potter ↔ Ministry: weight = 1
#   Harry Potter ↔ Apparate: weight = 2
#   Harry Potter ↔ witches: weight = 1
#   Harry Potter ↔ fireplaces: weight = 1
#   George ↔ Fred: weight = 1
#   George ↔ Ron Weasley: weight = 1
#   Floo Powder ↔ Arthur Weasley: weight = 2
#   Fred ↔ Ron Weasley: weight = 1
#   witches ↔ Arthur Weasley: weight = 1
#   witches ↔ Apparate: weight = 1
#   witches ↔ wizards: weight = 1
#   witches ↔ fireplaces: weight = 1
#   Order of the Phoenix ↔ Arthur Weasley: weight = 4
#   Order of the Phoenix ↔ wizarding world: weight = 1
#   Order of the Phoenix ↔ Ron Weasley: weight = 6
#   Order of the Phoenix ↔ Floo Network: weight = 1
#   Ministry ↔ Ron Weasley: weight = 1
#   Arthur Weasley ↔ Ron Weasley: weight = 24
#   Arthur Weasley ↔ Arthur Weasley: weight = 2
#   Arthur Weasley ↔ Floo Network: weight = 1
#   Arthur Weasley ↔ Apparate: weight = 2
#   Arthur Weasley ↔ wizards: weight = 1
#   Arthur Weasley ↔ fireplaces: weight = 1
#   Apparate ↔ Ron Weasley: weight = 1
#   Apparate ↔ wizards: weight = 1
#   Apparate ↔ fireplaces: weight = 1
#   Floo Network ↔ Ron Weasley: weight = 3
#   Floo Network ↔ Goblet of Fire: weight = 1
#   fireplaces ↔ wizards: weight = 1
#   wizarding world ↔ Ron Weasley: weight = 2
#   Goblet of Fire ↔ Ron Weasley: weight = 4
#   Ron Weasley ↔ Ron Weasley: weight = 2
# Total edge weight sum: 274
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 18.27
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.62
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 2.67
#
# [Processing prompt 13 of 548]
#
# ============================================================
# ANALYZING PROMPT: Who was the Hogwarts headmaster immediately before Albus Dumbledore?
# ============================================================
#
# Entities found in prompt: ['Albus Dumbledore', 'Hogwarts']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Albus Dumbledore ↔ Hogwarts: weight = 37
# Total edge weight sum: 37
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Albus Dumbledore: 93
#   Hogwarts: 59
# Total node frequency: 152
# Node count: 2
# Ratio: 76.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Albus Dumbledore: 545
#   Hogwarts: 808
# Total degree: 1353
# Average node degree entanglement: 676.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 1.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Albus Dumbledore: weight = 37
# Total edge weight sum: 37
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 18.50
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.50
#
# [Processing prompt 14 of 548]
#
# ============================================================
# ANALYZING PROMPT: Imagine stepping once more into the torchlit corridors of Hogwarts, the soft murmur of students drifting through the air and the old portraits whispering tales of days gone by. Before the half-moon grin and twinkling eyes of Albus Dumbledore graced the headmaster’s chair, another cherished figure held that mantle—guiding young witches and wizards through their first trials of magic. Who was the headmaster whose steady hand and quiet wisdom reigned over Hogwarts immediately before Dumbledore?
# ============================================================
#
# Entities found in prompt: ['Albus Dumbledore', 'Hogwarts', 'wizards', 'witches', 'magic']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Albus Dumbledore ↔ Hogwarts: weight = 37
#   Albus Dumbledore ↔ magic: weight = 1
#   Hogwarts ↔ wizards: weight = 1
#   Hogwarts ↔ witches: weight = 1
#   Hogwarts ↔ magic: weight = 1
#   wizards ↔ witches: weight = 1
#   wizards ↔ magic: weight = 1
#   witches ↔ magic: weight = 1
# Total edge weight sum: 44
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Albus Dumbledore: 93
#   Hogwarts: 59
#   wizards: 2
#   witches: 1
#   magic: 4
# Total node frequency: 159
# Node count: 5
# Ratio: 31.80
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Albus Dumbledore: 545
#   Hogwarts: 33
#   wizards: 115
#   witches: 808
#   magic: 51
# Total degree: 1552
# Average node degree entanglement: 310.40
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 8
# Possible edges: 10.0
# Density: 0.80
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Albus Dumbledore: weight = 37
#   Hogwarts ↔ magic: weight = 1
#   Hogwarts ↔ wizards: weight = 1
#   Hogwarts ↔ witches: weight = 1
#   witches ↔ magic: weight = 1
#   witches ↔ wizards: weight = 1
#   magic ↔ Albus Dumbledore: weight = 1
#   magic ↔ wizards: weight = 1
# Total edge weight sum: 44
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 8.80
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.20
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.60
#
# [Processing prompt 15 of 548]
#
# ============================================================
# ANALYZING PROMPT: Here’s a guided, step-by-step version that leads someone toward the correct name without stating it outright:
#
# 1. Timeframe Hint
#    • Dumbledore took over in the mid-20th century.
#    • Think back to the decades just before then—around the 1920s through the 1940s.
#
# 2. Administrative Clue
#    • This predecessor appears in a formal apology letter after a student was petrified in a certain school corridor.
#    • He was never accused of dark magic but often had to manage accidents that became scandalous.
#
# 3. Relationship Cue
#    • He was on good terms with the Ministry of Magic and often met with its officials to discuss curriculum changes.
#    • It wasn’t his first career—he began in another magical profession before entering Hogwarts leadership.
#
# 4. Name-Puzzle Hint
#    • His first name shares its first four letters with a famous explorer of human emotions (think “arm…”).
#    • His surname starts with a double consonant and ends in a soft “-et” sound.
#
# 5. Logical Deduction Steps
#    a) Identify Hogwarts heads in the century before Dumbledore.
#    b) Narrow to the one involved in the Chamber of Secrets incident paperwork.
#    c) Match that person’s name to the phonetic and spelling cues above.
#
# Put it all together, and you’ll arrive at the headmaster who served immediately before Albus Dumbledore. Who is he?
# ============================================================
#
# Entities found in prompt: ['Ministry of Magic', 'Albus Dumbledore', 'Dark magic', 'Hogwarts', 'letters', 'school']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Ministry of Magic ↔ Albus Dumbledore: weight = 25
#   Ministry of Magic ↔ Hogwarts: weight = 12
#   Ministry of Magic ↔ school: weight = 1
#   Albus Dumbledore ↔ Dark magic: weight = 1
#   Albus Dumbledore ↔ Hogwarts: weight = 37
#   Albus Dumbledore ↔ school: weight = 1
#   Hogwarts ↔ school: weight = 1
# Total edge weight sum: 78
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Ministry of Magic: 43
#   Albus Dumbledore: 93
#   Dark magic: 1
#   Hogwarts: 59
#   letters: 1
#   school: 1
# Total node frequency: 198
# Node count: 6
# Ratio: 33.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Ministry of Magic: 545
#   Albus Dumbledore: 808
#   Dark magic: 17
#   Hogwarts: 21
#   letters: 511
#   school: 35
# Total degree: 1937
# Average node degree entanglement: 322.83
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 7
# Possible edges: 15.0
# Density: 0.47
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Albus Dumbledore: weight = 37
#   Hogwarts ↔ Ministry of Magic: weight = 12
#   Hogwarts ↔ school: weight = 1
#   Albus Dumbledore ↔ Ministry of Magic: weight = 25
#   Albus Dumbledore ↔ Dark magic: weight = 1
#   Albus Dumbledore ↔ school: weight = 1
#   Ministry of Magic ↔ school: weight = 1
# Total edge weight sum: 78
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 13.00
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: inf
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.17
#
# [Processing prompt 16 of 548]
#
# ============================================================
# ANALYZING PROMPT: Drawing on J.K. Rowling’s own texts and official Wizarding World materials, please identify the Hogwarts headmaster who served immediately before Albus Dumbledore.  In your answer, cite at least one of the following:
#
#   •  Harry Potter and the Chamber of Secrets (Rowling, 1998), Chapter 13 (Tom Riddle’s Pensieve memory), where he refers to “Professor Dippet.”
#   •  The official Wizarding World website entry “Hogwarts: Headmasters & Mistresses” (Wizarding World, 2016), which lists all headmasters in order.
#   •  Any interview or Pottermore (now Wizarding World) excerpt in which Rowling confirms the name of Dumbledore’s predecessor.
#
# Who was Dumbledore’s immediate predecessor, and which source or quotation supports your answer?
# ============================================================
#
# Entities found in prompt: ['Albus Dumbledore', 'wizarding world', 'Harry Potter', 'headmasters', 'Tom Riddle', 'Hogwarts', 'Pensieve']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Albus Dumbledore ↔ wizarding world: weight = 1
#   Albus Dumbledore ↔ Harry Potter: weight = 95
#   Albus Dumbledore ↔ headmasters: weight = 2
#   Albus Dumbledore ↔ Tom Riddle: weight = 6
#   Albus Dumbledore ↔ Hogwarts: weight = 37
#   Albus Dumbledore ↔ Pensieve: weight = 3
#   wizarding world ↔ Harry Potter: weight = 3
#   wizarding world ↔ Hogwarts: weight = 1
#   Harry Potter ↔ headmasters: weight = 2
#   Harry Potter ↔ Tom Riddle: weight = 9
#   Harry Potter ↔ Hogwarts: weight = 61
#   Harry Potter ↔ Pensieve: weight = 4
#   Tom Riddle ↔ Hogwarts: weight = 3
#   Tom Riddle ↔ Pensieve: weight = 1
#   Hogwarts ↔ Pensieve: weight = 2
# Total edge weight sum: 230
#
# ...
# Redundancy ratio: 1.17
#
# [Processing prompt 541 of 548]
#
# ============================================================
# ANALYZING PROMPT: What effect does the spell “Protego” produce?
# ============================================================
#
# Entities found in prompt: []
# No entities found for analysis
#
# [Processing prompt 542 of 548]
#
# ============================================================
# ANALYZING PROMPT: Remember the thrill of your first wand duel at Hogwarts—your heart pounding as curses streaked toward you? Imagine the instant you whispered “Protego,” and a brilliant, invisible shield sprang to life between you and danger, deflecting every hex in a dazzling flash. What protective effect does the spell “Protego” produce?
# ============================================================
#
# Entities found in prompt: ['Hogwarts', 'duel', 'wand']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hogwarts ↔ duel: weight = 2
#   Hogwarts ↔ wand: weight = 2
# Total edge weight sum: 4
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hogwarts: 59
#   duel: 2
#   wand: 3
# Total node frequency: 64
# Node count: 3
# Ratio: 21.33
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hogwarts: 38
#   duel: 62
#   wand: 545
# Total degree: 645
# Average node degree entanglement: 215.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 2
# Possible edges: 3.0
# Density: 0.67
#
# --- FORMULA 5: Edge Weight Sum ---
#   duel ↔ Hogwarts: weight = 2
#   wand ↔ Hogwarts: weight = 2
# Total edge weight sum: 4
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 1.33
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.33
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.67
#
# [Processing prompt 543 of 548]
#
# ============================================================
# ANALYZING PROMPT: Below is a rephrased trivia prompt that gently leads the respondent toward the correct answer through structured hints and logical checkpoints—without ever stating it outright:
#
# —–
# Imagine you’re in a wizarding duel and you need to stop an incoming curse. Follow these thought-steps to uncover which charm achieves that effect:
#
# 1. Classification Check
#    • List three types of popular combat spells: one disarms, one stuns, one shields.
#    • You’re looking for the one that doesn’t remove a wand, nor knock someone out—but instead prevents harm.
#
# 2. Etymology Clue
#    • The incantation you seek begins with a prefix meaning “forth” or “for.”
#    • Its root is very close to our English word “protect.”
#
# 3. Wand Movement Hint
#    • While some charms require a sweeping arc, this particular one often ends with a quick, backward flick—almost as if you’re drawing a boundary in the air.
#
# 4. Common Usage
#    • In lessons with Professor Snape, Hermione praised it as “useful.”
#    • In duels, Harry first used it to deflect a stunning curse aimed at him.
#
# Question: Which spell, matching all of the above clues, creates a magical barrier that repels or absorbs incoming jinxes and curses?
# —–
#
# Work through each step, then name the charm that fits.
# ============================================================
#
# Entities found in prompt: ['English', 'combat', 'Charms', 'curse', 'duel', 'wand', 'Severus Snape', 'Hermione Granger', 'Harry Potter']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   English ↔ Severus Snape: weight = 1
#   English ↔ Hermione Granger: weight = 1
#   English ↔ Harry Potter: weight = 1
#   combat ↔ Hermione Granger: weight = 1
#   combat ↔ Harry Potter: weight = 1
#   Charms ↔ Severus Snape: weight = 1
#   Charms ↔ Hermione Granger: weight = 1
#   Charms ↔ Harry Potter: weight = 1
#   curse ↔ Severus Snape: weight = 1
#   curse ↔ Hermione Granger: weight = 1
#   curse ↔ Harry Potter: weight = 1
#   duel ↔ Harry Potter: weight = 2
#   wand ↔ Harry Potter: weight = 3
#   Severus Snape ↔ Hermione Granger: weight = 41
#   Severus Snape ↔ Harry Potter: weight = 60
#   Hermione Granger ↔ Harry Potter: weight = 134
# Total edge weight sum: 251
#
# --- FORMULA 2: Weighted Node Ratio ---
#   English: 1
#   combat: 1
#   Charms: 1
#   curse: 1
#   duel: 2
#   wand: 3
#   Severus Snape: 61
#   Hermione Granger: 133
#   Harry Potter: 199
# Total node frequency: 402
# Node count: 9
# Ratio: 44.67
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   English: 1290
#   combat: 39
#   Charms: 949
#   curse: 61
#   duel: 38
#   wand: 62
#   Severus Snape: 529
#   Hermione Granger: 16
#   Harry Potter: 45
# Total degree: 3029
# Average node degree entanglement: 336.56
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 16
# Possible edges: 36.0
# Density: 0.44
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Hermione Granger: weight = 134
#   Harry Potter ↔ Severus Snape: weight = 60
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ curse: weight = 1
#   Harry Potter ↔ duel: weight = 2
#   Harry Potter ↔ wand: weight = 3
#   Harry Potter ↔ English: weight = 1
#   Harry Potter ↔ combat: weight = 1
#   Harry Potter ↔ Charms: weight = 1
#   Hermione Granger ↔ Severus Snape: weight = 41
#   Hermione Granger ↔ Hermione Granger: weight = 1
#   Hermione Granger ↔ curse: weight = 1
#   Hermione Granger ↔ English: weight = 1
#   Hermione Granger ↔ combat: weight = 1
#   Hermione Granger ↔ Charms: weight = 1
#   English ↔ Severus Snape: weight = 1
#   Severus Snape ↔ Severus Snape: weight = 2
#   Severus Snape ↔ curse: weight = 1
#   Severus Snape ↔ Charms: weight = 1
# Total edge weight sum: 251
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 27.89
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.56
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.78
#
# [Processing prompt 544 of 548]
#
# ============================================================
# ANALYZING PROMPT: According to Harry Potter and the Order of the Phoenix (J.K. Rowling, 2003, Ch. 9)—where Professor Lupin introduces “Protego” as the Shield Charm capable of deflecting hexes and jinxes—and in J.K. Rowling’s official Pottermore entry (“Protego creates an invisible shield which blocks spells, curses, and physical objects”), what exact protective effect does casting the spell “Protego” produce?
# ============================================================
#
# Entities found in prompt: ['Order of the Phoenix', 'Harry Potter', 'Shield Charm', 'hexes', 'Remus Lupin']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Order of the Phoenix ↔ Harry Potter: weight = 15
#   Order of the Phoenix ↔ Remus Lupin: weight = 4
#   Harry Potter ↔ Shield Charm: weight = 1
#   Harry Potter ↔ hexes: weight = 1
#   Harry Potter ↔ Remus Lupin: weight = 31
# Total edge weight sum: 52
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Order of the Phoenix: 15
#   Harry Potter: 199
#   Shield Charm: 1
#   hexes: 1
#   Remus Lupin: 31
# Total node frequency: 247
# Node count: 5
# Ratio: 49.40
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Order of the Phoenix: 1290
#   Harry Potter: 218
#   Shield Charm: 338
#   hexes: 44
#   Remus Lupin: 20
# Total degree: 1910
# Average node degree entanglement: 382.00
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 5
# Possible edges: 10.0
# Density: 0.50
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Remus Lupin: weight = 31
#   Harry Potter ↔ Order of the Phoenix: weight = 15
#   Harry Potter ↔ hexes: weight = 1
#   Harry Potter ↔ Shield Charm: weight = 1
#   Order of the Phoenix ↔ Remus Lupin: weight = 4
# Total edge weight sum: 52
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 10.40
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.50
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.00
#
# [Processing prompt 545 of 548]
#
# ============================================================
# ANALYZING PROMPT: What subject does Professor McGonagall teach at Hogwarts?
# ============================================================
#
# Entities found in prompt: ['Hogwarts', 'Minerva McGonagall']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hogwarts ↔ Minerva McGonagall: weight = 19
# Total edge weight sum: 19
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Hogwarts: 59
#   Minerva McGonagall: 47
# Total node frequency: 106
# Node count: 2
# Ratio: 53.00
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Hogwarts: 492
#   Minerva McGonagall: 545
# Total degree: 1037
# Average node degree entanglement: 518.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 1.0
# Density: 1.00
#
# --- FORMULA 5: Edge Weight Sum ---
#   Minerva McGonagall ↔ Hogwarts: weight = 19
#   Minerva McGonagall ↔ Minerva McGonagall: weight = 2
# Total edge weight sum: 19
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 9.50
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.00
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.50
#
# [Processing prompt 546 of 548]
#
# ============================================================
# ANALYZING PROMPT: Close your eyes and picture the soaring towers of Hogwarts under a starlit sky, the echo of cloaks brushing against ancient stone as students scurry to their first class. Can you feel the familiar flutter of excitement in your chest? Now, think of the stern but kind figure standing tall at the front of that very classroom, robes swirling and eyes twinkling with pride. Which magical subject does Professor Minerva McGonagall pour her passion—and her legendary Transfiguration prowess—into teaching eager young witches and wizards?
# ============================================================
#
# Entities found in prompt: ['Professor Minerva McGonagall', 'Transfiguration', 'Hogwarts', 'wizards', 'witches', 'Stone']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Transfiguration ↔ Hogwarts: weight = 1
#   Hogwarts ↔ wizards: weight = 1
#   Hogwarts ↔ witches: weight = 1
#   wizards ↔ witches: weight = 1
# Total edge weight sum: 4
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Professor Minerva McGonagall: 1
#   Transfiguration: 6
#   Hogwarts: 59
#   wizards: 2
#   witches: 1
#   Stone: 1
# Total node frequency: 70
# Node count: 6
# Ratio: 11.67
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Professor Minerva McGonagall: 545
#   Transfiguration: 33
#   Hogwarts: 25
#   wizards: 109
#   witches: 51
#   Stone: 32
# Total degree: 795
# Average node degree entanglement: 132.50
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 4
# Possible edges: 15.0
# Density: 0.27
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ Transfiguration: weight = 1
#   Hogwarts ↔ wizards: weight = 1
#   Hogwarts ↔ witches: weight = 1
#   witches ↔ wizards: weight = 1
# Total edge weight sum: 4
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.67
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: inf
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.67
#
# [Processing prompt 547 of 548]
#
# ============================================================
# ANALYZING PROMPT: Let’s work through it in stages—no direct naming, just clues and logic:
#
# Step 1: Think of the magical art that’s all about changing one thing into another—say, a match into a needle, or a teacup into a rat. Which branch of magic focuses on altering shapes and forms?
#
# Step 2: Focus on the word itself. It begins with a Latin prefix meaning “across” or “beyond,” and ends with a root related to “form” or “shape.” Put them together.
#
# Step 3: Recall which senior Hogwarts professor—also Deputy Headmistress—specializes in this very discipline and runs the classroom where students learn to transform objects.
#
# Putting those pieces together leads you straight to the subject. What is it?
# ============================================================
#
# Entities found in prompt: ['Headmistress', 'Hogwarts', 'magic']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Hogwarts ↔ magic: weight = 1
# Total edge weight sum: 1
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Headmistress: 1
#   Hogwarts: 59
#   magic: 4
# Total node frequency: 64
# Node count: 3
# Ratio: 21.33
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Headmistress: 17
#   Hogwarts: 545
#   magic: 115
# Total degree: 677
# Average node degree entanglement: 225.67
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 1
# Possible edges: 3.0
# Density: 0.33
#
# --- FORMULA 5: Edge Weight Sum ---
#   Hogwarts ↔ magic: weight = 1
# Total edge weight sum: 1
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 0.33
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: inf
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 0.33
#
# [Processing prompt 548 of 548]
#
# ============================================================
# ANALYZING PROMPT: Here’s a revised trivia prompt that leans on J.K. Rowling’s own text to nudge respondents toward the right answer:
#
# “Drawn directly from J.K. Rowling’s canon, can you name Professor Minerva McGonagall’s teaching subject at Hogwarts?
#
# • In Harry Potter and the Philosopher’s Stone (1997), Chapter 10 “Halloween,” Rowling introduces McGonagall as ‘the sharp-eyed witch in emerald robes’ who demonstrates her mastery by Transfiguring her desk into a pig before breakfast.
# • In Harry Potter and the Order of the Phoenix (2003), Chapter 23 “Christmas on the Closed Ward,” she appears again, presiding over the Transfiguration staff meeting and discussing departmental strategy.
#
# Given these on-page references—both from Rowling herself—which subject does McGonagall teach?”
# ============================================================
#
# Entities found in prompt: ['Professor Minerva McGonagall', 'Order of the Phoenix', 'Philosopher’s Stone', 'Transfiguration', 'Harry Potter', 'Christmas', 'Halloween', 'breakfast', 'Hogwarts', 'meeting', 'witch']
#
# --- FORMULA 1: Edge Count Entanglement ---
#   Professor Minerva McGonagall ↔ Harry Potter: weight = 1
#   Order of the Phoenix ↔ Harry Potter: weight = 15
#   Order of the Phoenix ↔ breakfast: weight = 1
#   Order of the Phoenix ↔ Hogwarts: weight = 4
#   Philosopher’s Stone ↔ Harry Potter: weight = 1
#   Transfiguration ↔ Harry Potter: weight = 6
#   Transfiguration ↔ Hogwarts: weight = 1
#   Harry Potter ↔ Christmas: weight = 3
#   Harry Potter ↔ Halloween: weight = 3
#   Harry Potter ↔ breakfast: weight = 2
#   Harry Potter ↔ Hogwarts: weight = 61
#   Harry Potter ↔ meeting: weight = 1
#   Harry Potter ↔ witch: weight = 2
#   Halloween ↔ Hogwarts: weight = 1
#   breakfast ↔ Hogwarts: weight = 1
#   Hogwarts ↔ witch: weight = 1
# Total edge weight sum: 104
#
# --- FORMULA 2: Weighted Node Ratio ---
#   Professor Minerva McGonagall: 1
#   Order of the Phoenix: 15
#   Philosopher’s Stone: 1
#   Transfiguration: 6
#   Harry Potter: 199
#   Christmas: 3
#   Halloween: 3
#   breakfast: 2
#   Hogwarts: 59
#   meeting: 1
#   witch: 2
# Total node frequency: 292
# Node count: 11
# Ratio: 26.55
#
# --- FORMULA 3: Average Node Degree Entanglement ---
#   Professor Minerva McGonagall: 1290
#   Order of the Phoenix: 33
#   Philosopher’s Stone: 545
#   Transfiguration: 218
#   Harry Potter: 19
#   Christmas: 109
#   Halloween: 54
#   breakfast: 43
#   Hogwarts: 90
#   meeting: 71
#   witch: 32
# Total degree: 2504
# Average node degree entanglement: 227.64
#
# --- FORMULA 4: Subgraph Density ---
# Actual edges: 16
# Possible edges: 55.0
# Density: 0.29
#
# --- FORMULA 5: Edge Weight Sum ---
#   Harry Potter ↔ witch: weight = 2
#   Harry Potter ↔ Hogwarts: weight = 61
#   Harry Potter ↔ Professor Minerva McGonagall: weight = 1
#   Harry Potter ↔ Transfiguration: weight = 6
#   Harry Potter ↔ Philosopher’s Stone: weight = 1
#   Harry Potter ↔ Christmas: weight = 3
#   Harry Potter ↔ Harry Potter: weight = 2
#   Harry Potter ↔ Halloween: weight = 3
#   Harry Potter ↔ Order of the Phoenix: weight = 15
#   Harry Potter ↔ breakfast: weight = 2
#   Harry Potter ↔ meeting: weight = 1
#   Hogwarts ↔ Transfiguration: weight = 1
#   Hogwarts ↔ Halloween: weight = 1
#   Hogwarts ↔ witch: weight = 1
#   Hogwarts ↔ Order of the Phoenix: weight = 4
#   Hogwarts ↔ breakfast: weight = 1
#   Order of the Phoenix ↔ breakfast: weight = 1
# Total edge weight sum: 104
#
# --- FORMULA 6: Average Edge Weight Sum ---
# Average edge weight sum: 9.45
#
# --- FORMULA 7: Mean Shortest Path ---
# Mean shortest path length: 1.71
#
# --- FORMULA 8: Redundancy Ratio ---
# Redundancy ratio: 1.45
#
# All 548 prompts analyzed!
# Results saved to: prompt_analysis_results.txt

# %% [markdown]
# JSON

# %%
import pandas as pd
import networkx as nx
from itertools import combinations
import re
from collections import defaultdict
from pyvis.network import Network
import csv
import math
import json

# ===== Step 1: Load CSV =====
file_path = "KG - Sheet1.csv"  # your CSV file path
df = pd.read_csv(file_path)

# ===== Step 2: Alias map =====
alias_map = {
    "Harry": "Harry Potter",
    "Potter": "Harry Potter",
    "Lily": "Lily Potter",
    "James": "James Potter",
    "Hermione": "Hermione Granger",
    "Granger": "Hermione Granger",
    "Ron": "Ron Weasley",
    "Weasley": "Ron Weasley",
    "Dumbledore": "Albus Dumbledore",
    "Albus": "Albus Dumbledore",
    "Voldemort": "Lord Voldemort",
    "Number Four Privet Drive": "Privet Drive",
    "4 Privet Drive": "Privet Drive",
    "Hagrid": "Rubeus Hagrid",
    "Black": "Sirius Black",
    "Sirius": "Sirius Black",
    "McGonagall": "Minerva McGonagall",
    "Minerva": "Minerva McGonagall",
    "Professor McGonagall": "Minerva McGonagall",
    "Malfoy": "Draco Malfoy",
    "Draco": "Draco Malfoy",
    "Lupin": "Remus Lupin",
    "Remus": "Remus Lupin",
    "Neville": "Neville Longbottom",
    "Longbottom": "Neville Longbottom",
    "Snape": "Severus Snape",
    "Severus": "Severus Snape",
    "Professor Snape": "Severus Snape",
    "Dursleys": "Dudley Dursley",
    "Uncle Vernon": "Vernon Dursley",
    "Vernon": "Vernon Dursley",
    "Aunt Petunia": "Petunia Dursley",
    "Petunia": "Petunia Dursley",
    "Dudley": "Dudley Dursley",
    "Ginny": "Ginny Weasley",
    "Arthur": "Arthur Weasley",
    "Mr Weasley": "Arthur Weasley",
    "Mr. Weasley": "Arthur Weasley",
    "Molly": "Molly Weasley",
    "broom": "broomstick",
    "muggles": "muggle",
    "Platform 9¾": "Platform Nine and Three-Quarters",
    "Platform 9 3/4": "Platform Nine and Three-Quarters",
    "Platform Nine and 3/4": "Platform Nine and Three-Quarters",
    "Platform 9 and 3/4": "Platform Nine and Three-Quarters"
}

def normalize_name(name):
    name = name.strip()
    name = re.sub(r"^the\s+", "", name, flags=re.IGNORECASE)
    return alias_map.get(name, name)

# ===== Step 3: Build Graph =====
G = nx.Graph()
node_freq = defaultdict(int)

for _, row in df.iterrows():
    entities_str = row['Entities']
    entities = [normalize_name(e.strip()) for e in entities_str.split(',') if e.strip()]
    for entity in entities:
        node_freq[entity] += 1
    for i in range(len(entities)):
        for j in range(i + 1, len(entities)):
            e1, e2 = sorted([entities[i], entities[j]])
            if G.has_edge(e1, e2):
                G[e1][e2]['weight'] += 1
            else:
                G.add_edge(e1, e2, weight=1)

print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")

# ===== Step 4: Create HTML with Pyvis =====
net = Network(height="800px", width="100%", bgcolor="#222222", font_color="white")
net.barnes_hut()
for node in G.nodes():
    net.add_node(node, label=node, size=min(node_freq[node]*2, 50))
for source, target, data in G.edges(data=True):
    net.add_edge(source, target, value=data["weight"])
net.write_html("knowledge_graph.html")
print("Knowledge graph saved to knowledge_graph.html")

# ===== Step 5: Prompt Analysis Functions =====
def extract_entities_from_prompt(prompt, graph_nodes, alias_map):
    found_entities = []
    prompt_lower = prompt.lower()
    sorted_nodes = sorted(graph_nodes, key=len, reverse=True)
    for node in sorted_nodes:
        node_lower = node.lower()
        pattern = r'\b' + re.escape(node_lower).replace(r'\ ', r'\s+') + r'\b'
        if re.search(pattern, prompt_lower):
            found_entities.append(node)
    sorted_aliases = sorted(alias_map.keys(), key=len, reverse=True)
    for alias in sorted_aliases:
        alias_lower = alias.lower()
        target_entity = alias_map[alias]
        if target_entity in graph_nodes:
            pattern = r'\b' + re.escape(alias_lower).replace(r'\ ', r'\s+') + r'\b'
            if re.search(pattern, prompt_lower):
                if target_entity not in found_entities:
                    found_entities.append(target_entity)
    final_entities = []
    for entity in found_entities:
        if not any(entity != other and entity.lower() in other.lower() for other in found_entities):
            final_entities.append(entity)
    return final_entities

def calculate_edge_count_entanglement(entities, graph):
    total_weight = 0
    edges_found = []
    for i in range(len(entities)):
        for j in range(i + 1, len(entities)):
            e1, e2 = entities[i], entities[j]
            if graph.has_edge(e1, e2):
                weight = graph[e1][e2]['weight']
                total_weight += weight
                edges_found.append((e1, e2, weight))
    return total_weight, len(edges_found), edges_found

def calculate_weighted_node_ratio(entities, graph, node_freq):
    total_node_freq = sum(node_freq[entity] for entity in entities if entity in node_freq)
    node_count = len(entities)
    ratio = total_node_freq / node_count if node_count > 0 else 0
    return total_node_freq, node_count, ratio

def calculate_additional_metrics(entities, graph):
    results = {}
    if not entities:
        return results

    unique_entities = list(set(entities))
    n = len(unique_entities)

    degrees = [graph.degree(e) for e in unique_entities if e in graph]
    total_degree = sum(degrees)
    avg_degree = total_degree / n if n else 0
    results["avg_node_degree_entanglement"] = (degrees, total_degree, avg_degree)

    subgraph = graph.subgraph(unique_entities)
    _, actual_edges, edge_list = calculate_edge_count_entanglement(unique_entities, graph)
    edge_weights = [weight for _, _, weight in edge_list]
    
    possible_edges = n * (n - 1) / 2
    density = actual_edges / possible_edges if possible_edges else 0
    results["subgraph_density"] = (actual_edges, possible_edges, density)

    edge_weight_sum = sum(edge_weights)
    results["edge_weight_sum"] = (list(subgraph.edges(data=True)), edge_weight_sum)
    results["avg_edge_weight_sum"] = edge_weight_sum / n if n else 0

    if actual_edges > 0 and n > 1:
        try:
            mean_shortest_path = nx.average_shortest_path_length(subgraph)
        except nx.NetworkXError:
            mean_shortest_path = math.inf
    else:
        mean_shortest_path = 0
    results["mean_shortest_path"] = mean_shortest_path
    results["redundancy_ratio"] = actual_edges / n if n else 0

    return results

def analyze_prompt(prompt, graph, node_freq):
    result = {"prompt": prompt, "entities": [], "formulas": {}}

    entities = extract_entities_from_prompt(prompt, graph.nodes(), alias_map)
    result["entities"] = entities

    if not entities:
        return result

    # Formula 1
    if len(entities) >= 2:
        total_weight, edge_count, edges_found = calculate_edge_count_entanglement(entities, graph)
        result["formulas"]["formula1_edge_count"] = {
            "edges": [{"e1": e1, "e2": e2, "weight": weight} for e1, e2, weight in edges_found],
            "total_edge_weight": total_weight
        }

    # Formula 2
    total_node_freq, node_count, ratio = calculate_weighted_node_ratio(entities, graph, node_freq)
    result["formulas"]["formula2_weighted_node_ratio"] = {
        "node_freq": {e: node_freq.get(e, 0) for e in entities},
        "total_node_freq": total_node_freq,
        "node_count": node_count,
        "ratio": ratio
    }

    metrics = calculate_additional_metrics(entities, graph)

    degrees, total_degree, avg_deg = metrics.get("avg_node_degree_entanglement", ([], 0, 0))
    result["formulas"]["formula3_avg_node_degree_entanglement"] = {
        "degrees": dict(zip(entities, degrees)),
        "total_degree": total_degree,
        "average_degree": avg_deg
    }

    actual_edges, possible_edges, density = metrics.get("subgraph_density", (0,0,0))
    result["formulas"]["formula4_subgraph_density"] = {
        "actual_edges": actual_edges,
        "possible_edges": possible_edges,
        "density": density
    }

    edge_list, ew_sum = metrics.get("edge_weight_sum", ([],0))
    result["formulas"]["formula5_edge_weight_sum"] = {
        "edges": [{"e1": u, "e2": v, "weight": data["weight"]} for u,v,data in edge_list],
        "total_edge_weight_sum": ew_sum
    }

    result["formulas"]["formula6_avg_edge_weight_sum"] = metrics.get("avg_edge_weight_sum", 0)
    result["formulas"]["formula7_mean_shortest_path"] = metrics.get("mean_shortest_path", 0)
    result["formulas"]["formula8_redundancy_ratio"] = metrics.get("redundancy_ratio", 0)

    return result

# ===== Step 6: Load prompts from JSON =====
json_file_path = "harry_potter_questions.json"

with open(json_file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

prompts = []
for item in data:
    if "original_question" in item and item["original_question"]:
        prompts.append({"text": item["original_question"], "source": "original"})
    if "persuasive_versions" in item and item["persuasive_versions"]:
        for version_type, version_text in item["persuasive_versions"].items():
            prompts.append({"text": version_text, "source": f"persuasive ({version_type})"})

# ===== Step 7: Analyze all prompts and save JSON with simplified formula results =====
all_results = []
prompt_types_cycle = ["original", "emotional", "logical", "authority"]

for i, prompt_entry in enumerate(prompts):
    prompt_result = analyze_prompt(prompt_entry["text"], G, node_freq)
    
    # Keep only the final values for each formula
    simplified_formulas = {}
    formulas = prompt_result.get("formulas", {})
    
    simplified_formulas["formula1_edge_count_total_weight"] = formulas.get("formula1_edge_count", {}).get("total_edge_weight", 0)
    simplified_formulas["formula2_weighted_node_ratio"] = formulas.get("formula2_weighted_node_ratio", {}).get("ratio", 0)
    simplified_formulas["formula3_avg_node_degree_entanglement"] = formulas.get("formula3_avg_node_degree_entanglement", {}).get("average_degree", 0)
    simplified_formulas["formula4_subgraph_density"] = formulas.get("formula4_subgraph_density", {}).get("density", 0)
    simplified_formulas["formula5_edge_weight_sum"] = formulas.get("formula5_edge_weight_sum", {}).get("total_edge_weight_sum", 0)
    simplified_formulas["formula6_avg_edge_weight_sum"] = formulas.get("formula6_avg_edge_weight_sum", 0)
    simplified_formulas["formula7_mean_shortest_path"] = formulas.get("formula7_mean_shortest_path", 0)
    simplified_formulas["formula8_redundancy_ratio"] = formulas.get("formula8_redundancy_ratio", 0)
    
    # Build final prompt entry
    final_result = {
        "prompt": prompt_entry["text"],
        "source": prompt_entry["source"],
        "prompt_type": prompt_types_cycle[i % 4],
        "formulas": simplified_formulas
    }
    
    all_results.append(final_result)

with open("prompt_analysis_results.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, ensure_ascii=False, indent=2)

print(f"\nAll {len(prompts)} prompts analyzed!")
print("Results saved to: prompt_analysis_results.json")
# Out:
# Graph created with 1296 nodes and 35922 edges
# Knowledge graph saved to knowledge_graph.html
#
# All 548 prompts analyzed!
# Results saved to: prompt_analysis_results.json
